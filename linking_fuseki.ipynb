# %% [markdown]
# # Preprocessing

# %%
import pickle
import json
import os
from preprocessing import clean_gt, clean_raw, label_entity

# %%
split = pickle.load(open('data/train_test_eval_filenames_new.pkl', 'rb'))
split
# Out:
# {'train': ['sbz-002_1940_115_0223.txt',
#   'dkm-001_1941_001_0431.txt',
#   'dkm-001_1941_001_0438.txt',
#   'dkm-001_1941_001_0441.txt',
#   'sbz-002_1940_115_0222.txt',
#   'sbz-002_1965_083_3175.txt',
#   'sbz-002_1940_115_0224.txt',
#   'sbz-002_1895_025_0676.txt',
#   'sbz-002_1940_115_0218.txt',
#   'sbz-002_1895_025_0679.txt',
#   'dkm-003_2010_070_0050.txt',
#   'sbz-002_1940_115_0221.txt',
#   'sbz-004_2010_136_0884.txt',
#   'sbz-002_1940_115_0220.txt',
#   'sbz-002_1965_083_3184.txt',
#   'sbz-002_1895_025_0678.txt',
#   'sbz-002_1965_083_3188.txt',
#   'dkm-001_1941_001_0423.txt',
#   'sbz-004_2010_136_0887.txt',
#   'sbz-004_2010_136_0890.txt',
#   'dkm-003_2010_070_0053.txt',
#   'dkm-001_1941_001_0434.txt',
#   'sbz-004_2010_136_0883.txt',
#   'sbz-004_2010_136_0882.txt',
#   'sbz-002_1965_083_3178.txt',
#   'dkm-001_1941_001_0430.txt',
#   'dkm-003_2010_070_0056.txt',
#   'sbz-004_2010_136_0885.txt',
#   'sbz-002_1965_083_3173.txt',
#   'sbz-002_1965_083_3172.txt',
#   'sbz-002_1965_083_3180.txt',
#   'dkm-001_1941_001_0433.txt',
#   'sbz-002_1965_083_3167.txt',
#   'dkm-001_1941_001_0443.txt',
#   'dkm-001_1941_001_0437.txt',
#   'sbz-004_2010_136_0880.txt',
#   'dkm-003_2010_070_0059.txt',
#   'dkm-003_2010_070_0051.txt',
#   'sbz-004_2010_136_0896.txt',
#   'dkm-003_2010_070_0049.txt',
#   'sbz-002_1965_083_3183.txt',
#   'dkm-003_2010_070_0048.txt',
#   'sbz-004_2010_136_0878.txt',
#   'sbz-004_2010_136_0897.txt',
#   'dkm-003_2010_070_0045.txt',
#   'sbz-004_2010_136_0889.txt',
#   'sbz-002_1965_083_3171.txt',
#   'dkm-001_1941_001_0427.txt',
#   'dkm-003_2010_070_0047.txt',
#   'sbz-004_2010_136_0894.txt',
#   'dkm-001_1941_001_0425.txt',
#   'dkm-003_2010_070_0042.txt',
#   'sbz-002_1940_115_0219.txt',
#   'sbz-002_1965_083_3181.txt',
#   'dkm-001_1941_001_0440.txt',
#   'sbz-002_1940_115_0214.txt',
#   'sbz-004_2010_136_0892.txt',
#   'sbz-002_1895_025_0682.txt',
#   'sbz-002_1965_083_3186.txt',
#   'dkm-001_1941_001_0436.txt',
#   'dkm-003_2010_070_0052.txt',
#   'dkm-001_1941_001_0439.txt',
#   'sbz-002_1965_083_3174.txt',
#   'sbz-002_1965_083_3187.txt',
#   'sbz-002_1965_083_3168.txt',
#   'dkm-003_2010_070_0055.txt',
#   'dkm-003_2010_070_0057.txt',
#   'dkm-001_1941_001_0424.txt',
#   'sbz-002_1965_083_3169.txt',
#   'dkm-001_1941_001_0428.txt',
#   'dkm-001_1941_001_0429.txt',
#   'dkm-001_1941_001_0435.txt',
#   'sbz-002_1965_083_3177.txt',
#   'dkm-003_2010_070_0041.txt',
#   'sbz-002_1940_115_0213.txt',
#   'dkm-003_2010_070_0046.txt',
#   'sbz-002_1940_115_0217.txt',
#   'sbz-002_1895_025_0675.txt',
#   'sbz-002_1965_083_3185.txt',
#   'sbz-004_2010_136_0888.txt',
#   'sbz-004_2010_136_0895.txt',
#   'dkm-001_1941_001_0426.txt',
#   'dkm-001_1941_001_0432.txt',
#   'dkm-003_2010_070_0044.txt',
#   'sbz-002_1895_025_0683.txt',
#   'sbz-002_1965_083_3182.txt',
#   'dkm-001_1941_001_0442.txt',
#   'sbz-004_2010_136_0893.txt',
#   'dkm-003_2010_070_0043.txt',
#   'sbz-004_2010_136_0879.txt',
#   'sbz-004_2010_136_0881.txt',
#   'sbz-002_1895_025_0681.txt',
#   'sbz-002_1965_083_3170.txt',
#   'sbz-002_1965_083_3179.txt'],
#  'test': ['sbz-003_1990_108_1800.txt',
#   'dkm-003_1990_050_0388.txt',
#   'dkm-003_1990_050_0380.txt',
#   'sbz-003_1990_108_1798.txt',
#   'dkm-003_1990_050_0383.txt',
#   'sbz-003_1990_108_1796.txt',
#   'dkm-003_1990_050_0397.txt',
#   'dkm-003_1990_050_0393.txt',
#   'dkm-003_1990_050_0385.txt',
#   'dkm-003_1990_050_0386.txt',
#   'dkm-003_1990_050_0391.txt',
#   'dkm-003_1990_050_0389.txt',
#   'dkm-003_1990_050_0382.txt',
#   'sbz-003_1990_108_1794.txt',
#   'dkm-003_1990_050_0399.txt',
#   'dkm-003_1990_050_0381.txt',
#   'sbz-003_1990_108_1795.txt',
#   'dkm-003_1990_050_0392.txt',
#   'dkm-003_1990_050_0384.txt',
#   'sbz-003_1990_108_1801.txt',
#   'dkm-003_1990_050_0395.txt',
#   'dkm-003_1990_050_0400.txt',
#   'dkm-003_1990_050_0396.txt',
#   'sbz-003_1990_108_1793.txt',
#   'sbz-003_1990_108_1797.txt',
#   'dkm-003_1990_050_0394.txt',
#   'sbz-003_1990_108_1799.txt',
#   'dkm-003_1990_050_0398.txt',
#   'dkm-003_1990_050_0387.txt',
#   'dkm-003_1990_050_0390.txt'],
#  'eval': ['sbz-002_1895_025_0680.txt',
#   'dkm-003_2010_070_0054.txt',
#   'sbz-002_1940_115_0216.txt',
#   'dkm-003_2010_070_0040.txt',
#   'sbz-004_2010_136_0886.txt',
#   'sbz-002_1940_115_0215.txt',
#   'sbz-002_1965_083_3176.txt',
#   'sbz-004_2010_136_0891.txt',
#   'dkm-003_2010_070_0058.txt',
#   'sbz-002_1895_025_0677.txt']}

# %%
#train = 94, test = 30, eval = 10

# %%
# import random
# new_split = {"train":[], "test": [], "eval": []}
# for key in split:
#     for page in split[key]:
#         mag = page.split("_")[0].split("-")[0]
#         year = page.split("_")[1]
        
#         if mag == "dkm" and (year == "1941" or year == "2010"):
#             new_split["train"].append(page)
#         if (year == "1990"):
#             new_split["test"].append(page)
#         if mag =="sbz" and (year == "1895" or year == "1940" or year == "1965" or year == "2010"):
#             new_split["train"].append(page)

# eval_set = random.sample(new_split["train"], int(len(new_split["train"])/10)) #set 10% of train aside for eval
# for page in eval_set:
#     new_split["train"].remove(page)
# new_split["eval"] = eval_set

# with open('train_test_eval_filenames_new.pkl', 'wb') as out:
#     pickle.dump(new_split, out)

# %%
"""
data = {
    "train": [],
    "test": [],
    "eval": []
}
gt_data = []
for mag in ["dkm", "sbz"]:
    for year in os.listdir(f'data/raw/link/{mag}'):
        with open(os.path.join("data/raw/link", mag, year)) as f:
            input_linked = json.load(f)
        with open(os.path.join("data/ground-truth", mag, year)) as f:
            gt = json.load(f)
        gt = clean_gt(gt)
        gt_data += gt
        input_linked = clean_raw(input_linked)

        #due to non-determinism in the flair NER:
        all_refs_gt = [g["page"]+g["coord"] for g in gt] 
        all_refs_linked = [ent["page"]+ent["coord"] for l in input_linked for ent in l]
        all_valid_refs = set(all_refs_gt).intersection(set(all_refs_linked))

        for ent_variations in input_linked:
            for key in split:
                ent_instances = []
                for ent in ent_variations:
                    if ent["page"] in split[key]:
                        if (ent["page"]+ent["coord"]) in all_valid_refs:
                            ent_instances.append({"ent": ent, "label": label_entity(ent, gt)})
                if ent_instances:
                    data[key].append(ent_instances)
"""

# %%
split
# Out:
# 'test'

# %%
data_statistics = {
    "train": [],
    "test": [],
    "eval": []
}
gt_data_statistics = []
for mag in ["dkm", "sbz"]:
    for year in os.listdir(f'data/raw/link/{mag}'):
        with open(os.path.join("data/raw/link", mag, year)) as f:
            input_linked = json.load(f)
        with open(os.path.join("data/ground-truth", mag, year)) as f:
            gt = json.load(f)
        gt = clean_gt(gt)
        gt_data_statistics += gt
        input_linked = clean_raw(input_linked)

        #due to non-determinism in the flair NER:
        all_refs_gt = [g["page"]+g["coord"] for g in gt] 
        all_refs_linked = [ent["page"]+ent["coord"] for l in input_linked for ent in l]
        all_valid_refs = set(all_refs_gt).intersection(set(all_refs_linked))

        for ent_variations in input_linked:
            for key in split:
                ent_instances = []
                for ent in ent_variations:
                    if ent["page"] in split[key]:
                        if (ent["page"]+ent["coord"]) in all_valid_refs:
                            ent_instances.append({"ent": ent, "label": label_entity(ent, gt), "mag-year": str(mag)+"-"+year.split(".")[0]})
                if ent_instances:
                    data_statistics[key].append(ent_instances)

# %%
data_statistics_global = data_statistics["train"]+data_statistics["test"]+data_statistics["eval"]
data_statistics_global
# Out:
# [[{'ent': {'lastname': '',
#     'firstname': 'Nicole',
#     'abbr_firstname': [],
#     'other': [['S.'], ['Fräulein', 'S.']],
#     'name': None,
#     'profession': [],
#     'places': ['Bourg'],
#     'page': 'dkm-001_1941_001_0439.txt',
#     'year': '1941',
#     'coord': '913,1772,110,21'},
#    'label': '',
#    'mag-year': 'dkm-1941'},
#   {'ent': {'lastname': '',
#     'firstname': 'Nicole',
#     'abbr_firstname': [],
#     'other': [['S.'], ['Fräulein', 'S.']],
#     'name': None,
#     'profession': [],
#     'places': ['Bourg'],
#     'page': 'dkm-001_1941_001_0439.txt',
#     'year': '1941',
#     'coord': '1039,1771,23,22'},
#    'label': '',
#    'mag-year': 'dkm-1941'}],
#  [{'ent': {'lastname': '',
#     'firstname': 'Ruth',
#     'abbr_firstname': ['H.'],
#     'other': [],
#     'name': 'Ruth H.',
#     'profession': [],
#     'places': ['Zürich'],
#     'page': 'dkm-001_1941_001_0438.txt',
#     'year': '1941',
#     'coord': '589,1197,25,16'},
#    'label': '',
#    'mag-year': 'dkm-1941'},
#   {'ent': {'lastname': '',
#     'firstname': 'Ruth',
#     'abbr_firstname': ['H.'],
#     'other': [],
#     'name': 'Ruth H.',
#     'profession': [],
#     'places': ['Zürich'],
#     'page': 'dkm-001_1941_001_0438.txt',
#     'year': '1941',
#     'coord': '516,1197,56,16'},
#    'label': '',
#    'mag-year': 'dkm-1941'}],
#  [{'ent': {'lastname': '',
#     'firstname': 'Andres',
#     'abbr_firstname': [],
#     'other': [],
#     'name': None,
#     'profession': [],
#     'places': ['Zürich', 'Zürich'],
#     'page': 'dkm-001_1941_001_0440.txt',
#     'year': '1941',
#     'coord': '478,857,71,28'},
#    'label': '',
#    'mag-year': 'dkm-1941'},
#   {'ent': {'lastname': '',
#     'firstname': 'Andres',
#     'abbr_firstname': [],
#     'other': [],
#     'name': None,
#     'profession': [],
#     'places': ['Zürich', 'Zürich'],
#     'page': 'dkm-001_1941_001_0440.txt',
#     'year': '1941',
#     'coord': '563,857,91,21'},
#    'label': '',
#    'mag-year': 'dkm-1941'}],
#  [{'ent': {'lastname': '',
#     'firstname': '',
#     'abbr_firstname': [],
#     'other': [['Hieroshige']],
#     'name': 'Hieroshige',
#     'profession': [],
#     'places': ['Waldstatt', 'Ostschweiz'],
#     'page': 'dkm-001_1941_001_0427.txt',
#     'year': '1941',
#     'coord': '1803,2281,145,28'},
#    'label': '111268302X',
#    'mag-year': 'dkm-1941'}],
#  [{'ent': {'lastname': '',
#     'firstname': '',
#     'abbr_firstname': [],
#     'other': [['Frau', 'M.']],
#     'name': 'Frau M.',
#     'profession': [],
#     'places': ['Nordschweiz'],
#     'page': 'dkm-001_1941_001_0437.txt',
#     'year': '1941',
#     'coord': '1530,1743,52,17'},
#    'label': '',
#    'mag-year': 'dkm-1941'},
#   {'ent': {'lastname': '',
#     'firstname': '',
#     'abbr_firstname': [],
#     'other': [['Frau', 'M.']],
#     'name': 'Frau M.',
#     'profession': [],
#     'places': ['Nordschweiz'],
#     'page': 'dkm-001_1941_001_0437.txt',
#     'year': '1941',
#     'coord': '1597,1744,26,16'},
#    'label': '',
#    'mag-year': 'dkm-1941'}],
#  [{'ent': {'lastname': 'Andres-Schurter',
#     'firstname': '',
#     'abbr_firstname': ['C.'],
#     'other': [],
#     'name': 'C. Andres-Schurter',
#     'profession': [],
#     'places': ['Zürich'],
#     'page': 'dkm-001_1941_001_0440.txt',
#     'year': '1941',
#     'coord': '228,677,23,22'},
#    'label': '',
#    'mag-year': 'dkm-1941'},
#   {'ent': {'lastname': 'Andres-Schurter',
#     'firstname': '',
#     'abbr_firstname': ['C.'],
#     'other': [],
#     'name': 'C. Andres-Schurter',
#     'profession': [],
#     'places': ['Zürich'],
#     'page': 'dkm-001_1941_001_0440.txt',
#     'year': '1941',
#     'coord': '261,676,226,27'},
#    'label': '',
#    'mag-year': 'dkm-1941'},
#   {'ent': {'lastname': 'Andres-Schurter',
#     'firstname': '',
#     'abbr_firstname': ['C.'],
#     'other': [],
#     'name': 'C. Andres-Schurter',
#     'profession': [],
#     'places': ['Zürich'],
#     'page': 'dkm-001_1941_001_0440.txt',
#     'year': '1941',
#     'coord': '156,677,62,22'},
#    'label': '',
#    'mag-year': 'dkm-1941'}],
#  [{'ent': {'lastname': 'Bernoulli',
#     'firstname': 'Christoph',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Christoph Bernoulli',
#     'profession': [],
#     'places': ['Bern',
#      'Bourg',
#      'Urnäsch',
#      'Zurich',
#      'Zürich',
#      'Welt',
#      'Genf',
#      'Zürichsees',
#      'Heiden',
#      'Lausanne',
#      'Luzern',
#      'Reute',
#      'St. Gallen',
#      'Appenzellerland',
#      'Basel'],
#     'page': 'dkm-001_1941_001_0428.txt',
#     'year': '1941',
#     'coord': '1304,2108,123,29'},
#    'label': '118509934',
#    'mag-year': 'dkm-1941'},
#   {'ent': {'lastname': 'Bernoulli',
#     'firstname': 'Christoph',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Christoph Bernoulli',
#     'profession': [],
#     'places': ['Bern',
#      'Bourg',
#      'Urnäsch',
#      'Zurich',
#      'Zürich',
#      'Welt',
#      'Genf',
#      'Zürichsees',
#      'Heiden',
#      'Lausanne',
#      'Luzern',
#      'Reute',
#      'St. Gallen',
#      'Appenzellerland',
#      'Basel'],
#     'page': 'dkm-001_1941_001_0428.txt',
#     'year': '1941',
#     'coord': '1440,2108,119,22'},
#    'label': '118509934',
#    'mag-year': 'dkm-1941'}],
#  [{'ent': {'lastname': 'Breitenmoser',
#     'firstname': 'Appenzellem',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Appenzellem Breitenmoser',
#     'profession': [],
#     'places': ['Hundwil', 'Bödeli'],
#     'page': 'dkm-001_1941_001_0431.txt',
#     'year': '1941',
#     'coord': '1267,2309,182,25'},
#    'label': '',
#    'mag-year': 'dkm-1941'}],
#  [{'ent': {'lastname': 'Broger',
#     'firstname': 'Armin',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Armin Broger',
#     'profession': [],
#     'places': ['Zürich'],
#     'page': 'dkm-001_1941_001_0442.txt',
#     'year': '1941',
#     'coord': '1342,1162,95,28'},
#    'label': '',
#    'mag-year': 'dkm-1941'},
#   {'ent': {'lastname': 'Broger',
#     'firstname': 'Armin',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Armin Broger',
#     'profession': [],
#     'places': ['Zürich'],
#     'page': 'dkm-001_1941_001_0442.txt',
#     'year': '1941',
#     'coord': '1240,1162,82,21'},
#    'label': '',
#    'mag-year': 'dkm-1941'},
#   {'ent': {'lastname': 'Broger',
#     'firstname': 'Armin',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Armin Broger',
#     'profession': [],
#     'places': ['Zürich'],
#     'page': 'dkm-001_1941_001_0442.txt',
#     'year': '1941',
#     'coord': '1353,1234,95,28'},
#    'label': '',
#    'mag-year': 'dkm-1941'},
#   {'ent': {'lastname': 'Broger',
#     'firstname': 'Armin',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Armin Broger',
#     'profession': [],
#     'places': ['Zürich'],
#     'page': 'dkm-001_1941_001_0442.txt',
#     'year': '1941',
#     'coord': '1240,1234,83,21'},
#    'label': '',
#    'mag-year': 'dkm-1941'},
#   {'ent': {'lastname': 'Broger',
#     'firstname': 'Armin',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Armin Broger',
#     'profession': [],
#     'places': ['Zürich'],
#     'page': 'dkm-001_1941_001_0442.txt',
#     'year': '1941',
#     'coord': '1435,1485,88,28'},
#    'label': '',
#    'mag-year': 'dkm-1941'},
#   {'ent': {'lastname': 'Broger',
#     'firstname': 'Armin',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Armin Broger',
#     'profession': [],
#     'places': ['Zürich'],
#     'page': 'dkm-001_1941_001_0442.txt',
#     'year': '1941',
#     'coord': '1329,1485,84,21'},
#    'label': '',
#    'mag-year': 'dkm-1941'},
#   {'ent': {'lastname': 'Broger',
#     'firstname': 'Armin',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Armin Broger',
#     'profession': [],
#     'places': ['Zürich'],
#     'page': 'dkm-001_1941_001_0442.txt',
#     'year': '1941',
#     'coord': '2033,2164,88,26'},
#    'label': '',
#    'mag-year': 'dkm-1941'},
#   {'ent': {'lastname': 'Broger',
#     'firstname': 'Armin',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Armin Broger',
#     'profession': [],
#     'places': ['Zürich'],
#     'page': 'dkm-001_1941_001_0442.txt',
#     'year': '1941',
#     'coord': '1915,2164,83,21'},
#    'label': '',
#    'mag-year': 'dkm-1941'}],
#  [{'ent': {'lastname': 'Dörig',
#     'firstname': 'Boger',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Boger Dörig',
#     'profession': ['Boger'],
#     'places': ['Zürich', 'Schweiz', 'Appenzell', 'London'],
#     'page': 'dkm-001_1941_001_0442.txt',
#     'year': '1941',
#     'coord': '544,2482,86,27'},
#    'label': '',
#    'mag-year': 'dkm-1941'},
#   {'ent': {'lastname': 'Dörig',
#     'firstname': 'Boger',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Boger Dörig',
#     'profession': ['Boger'],
#     'places': ['Zürich', 'Schweiz', 'Appenzell', 'London'],
#     'page': 'dkm-001_1941_001_0442.txt',
#     'year': '1941',
#     'coord': '445,2480,88,29'},
#    'label': '',
#    'mag-year': 'dkm-1941'},
#   {'ent': {'lastname': 'Dörig',
#     'firstname': 'Boger',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Boger Dörig',
#     'profession': ['Boger'],
#     'places': ['Zürich', 'Schweiz', 'Appenzell', 'London'],
#     'page': 'dkm-001_1941_001_0442.txt',
#     'year': '1941',
#     'coord': '351,2480,79,28'},
#    'label': '',
#    'mag-year': 'dkm-1941'},
#   {'ent': {'lastname': 'Dörig',
#     'firstname': 'Boger',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Boger Dörig',
#     'profession': ['Boger'],
#     'places': ['Zürich', 'Schweiz', 'Appenzell', 'London'],
#     'page': 'dkm-001_1941_001_0442.txt',
#     'year': '1941',
#     'coord': '374,2630,73,27'},
#    'label': '',
#    'mag-year': 'dkm-1941'},
#   {'ent': {'lastname': 'Dörig',
#     'firstname': 'Boger',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Boger Dörig',
#     'profession': ['Boger'],
#     'places': ['Zürich', 'Schweiz', 'Appenzell', 'London'],
#     'page': 'dkm-001_1941_001_0442.txt',
#     'year': '1941',
#     'coord': '280,2629,76,28'},
#    'label': '',
#    'mag-year': 'dkm-1941'},
#   {'ent': {'lastname': 'Dörig',
#     'firstname': 'Boger',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Boger Dörig',
#     'profession': ['Boger'],
#     'places': ['Zürich', 'Schweiz', 'Appenzell', 'London'],
#     'page': 'dkm-001_1941_001_0442.txt',
#     'year': '1941',
#     'coord': '1625,808,79,28'},
#    'label': '',
#    'mag-year': 'dkm-1941'}],
#  [{'ent': {'lastname': 'Farner-Hasler',
#     'firstname': 'Agnes',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Agnes Farner-Hasler',
#     'profession': [],
#     'places': ['Zürich'],
#     'page': 'dkm-001_1941_001_0437.txt',
#     'year': '1941',
#     'coord': '323,2761,165,21'},
#    'label': '',
#    'mag-year': 'dkm-1941'},
#   {'ent': {'lastname': 'Farner-Hasler',
#     'firstname': 'Agnes',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Agnes Farner-Hasler',
#     'profession': [],
#     'places': ['Zürich'],
#     'page': 'dkm-001_1941_001_0437.txt',
#     'year': '1941',
#     'coord': '246,2760,66,22'},
#    'label': '',
#    'mag-year': 'dkm-1941'}],
#  [{'ent': {'lastname': 'Heim',
#     'firstname': 'Franz Anton',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Franz Anton Heim',
#     'profession': [],
#     'places': [],
#     'page': 'dkm-001_1941_001_0424.txt',
#     'year': '1941',
#     'coord': '937,1883,115,21'},
#    'label': '104079959',
#    'mag-year': 'dkm-1941'},
#   {'ent': {'lastname': 'Heim',
#     'firstname': 'Franz Anton',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Franz Anton Heim',
#     'profession': [],
#     'places': [],
#     'page': 'dkm-001_1941_001_0424.txt',
#     'year': '1941',
#     'coord': '1063,1883,118,21'},
#    'label': '104079959',
#    'mag-year': 'dkm-1941'},
#   {'ent': {'lastname': 'Heim',
#     'firstname': 'Franz Anton',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Franz Anton Heim',
#     'profession': [],
#     'places': [],
#     'page': 'dkm-001_1941_001_0424.txt',
#     'year': '1941',
#     'coord': '1193,1883,94,21'},
#    'label': '104079959',
#    'mag-year': 'dkm-1941'}],
#  [{'ent': {'lastname': 'Haemmerli-Schindler',
#     'firstname': 'Gertrud',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Gertrud Haemmerli-Schindler',
#     'profession': ['Präsidentin'],
#     'places': ['Bern', 'Turnegg', 'Zürich'],
#     'page': 'dkm-001_1941_001_0436.txt',
#     'year': '1941',
#     'coord': '1539,474,130,17'},
#    'label': '126361266',
#    'mag-year': 'dkm-1941'},
#   {'ent': {'lastname': 'Haemmerli-Schindler',
#     'firstname': 'Gertrud',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Gertrud Haemmerli-Schindler',
#     'profession': ['Präsidentin'],
#     'places': ['Bern', 'Turnegg', 'Zürich'],
#     'page': 'dkm-001_1941_001_0436.txt',
#     'year': '1941',
#     'coord': '1294,473,237,23'},
#    'label': '126361266',
#    'mag-year': 'dkm-1941'},
#   {'ent': {'lastname': 'Haemmerli-Schindler',
#     'firstname': 'Gertrud',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Gertrud Haemmerli-Schindler',
#     'profession': ['Präsidentin'],
#     'places': ['Bern', 'Turnegg', 'Zürich'],
#     'page': 'dkm-001_1941_001_0436.txt',
#     'year': '1941',
#     'coord': '1203,475,82,17'},
#    'label': '126361266',
#    'mag-year': 'dkm-1941'}],
#  [{'ent': {'lastname': 'Heuscher',
#     'firstname': '',
#     'abbr_firstname': [],
#     'other': [],
#     'name': None,
#     'profession': [],
#     'places': ['Waldstatt', 'Ostschweiz'],
#     'page': 'dkm-001_1941_001_0427.txt',
#     'year': '1941',
#     'coord': '1941,2129,122,21'},
#    'label': '1018268405',
#    'mag-year': 'dkm-1941'}],
#  [{'ent': {'lastname': 'Iieuscher',
#     'firstname': 'Johann Jacob',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Johann Jacob Iieuscher',
#     'profession': [],
#     'places': ['Waldstatt', 'Ostschweiz'],
#     'page': 'dkm-001_1941_001_0427.txt',
#     'year': '1941',
#     'coord': '437,2279,184,21'},
#    'label': '1018268405',
#    'mag-year': 'dkm-1941'},
#   {'ent': {'lastname': 'Iieuscher',
#     'firstname': 'Johann Jacob',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Johann Jacob Iieuscher',
#     'profession': [],
#     'places': ['Waldstatt', 'Ostschweiz'],
#     'page': 'dkm-001_1941_001_0427.txt',
#     'year': '1941',
#     'coord': '315,2278,104,22'},
#    'label': '1018268405',
#    'mag-year': 'dkm-1941'},
#   {'ent': {'lastname': 'Iieuscher',
#     'firstname': 'Johann Jacob',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Johann Jacob Iieuscher',
#     'profession': [],
#     'places': ['Waldstatt', 'Ostschweiz'],
#     'page': 'dkm-001_1941_001_0427.txt',
#     'year': '1941',
#     'coord': '159,2279,137,21'},
#    'label': '1018268405',
#    'mag-year': 'dkm-1941'}],
#  [{'ent': {'lastname': 'Jaberg',
#     'firstname': '',
#     'abbr_firstname': ['P.'],
#     'other': [],
#     'name': 'P. Jaberg',
#     'profession': [],
#     'places': ['Nordschweiz', 'Zürich', 'Hornergasse', 'Turnegg'],
#     'page': 'dkm-001_1941_001_0437.txt',
#     'year': '1941',
#     'coord': '950,2072,25,21'},
#    'label': '',
#    'mag-year': 'dkm-1941'},
#   {'ent': {'lastname': 'Jaberg',
#     'firstname': '',
#     'abbr_firstname': ['P.'],
#     'other': [],
#     'name': 'P. Jaberg',
#     'profession': [],
#     'places': ['Nordschweiz', 'Zürich', 'Hornergasse', 'Turnegg'],
#     'page': 'dkm-001_1941_001_0437.txt',
#     'year': '1941',
#     'coord': '879,2072,62,21'},
#    'label': '',
#    'mag-year': 'dkm-1941'},
#   {'ent': {'lastname': 'Jaberg',
#     'firstname': '',
#     'abbr_firstname': ['P.'],
#     'other': [],
#     'name': 'P. Jaberg',
#     'profession': [],
#     'places': ['Nordschweiz', 'Zürich', 'Hornergasse', 'Turnegg'],
#     'page': 'dkm-001_1941_001_0437.txt',
#     'year': '1941',
#     'coord': '984,2072,96,28'},
#    'label': '',
#    'mag-year': 'dkm-1941'}],
#  [{'ent': {'lastname': 'Knöpfel',
#     'firstname': 'Johann Jacob',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Johann Jacob Knöpfel',
#     'profession': [],
#     'places': ['Urnäsch'],
#     'page': 'dkm-001_1941_001_0433.txt',
#     'year': '1941',
#     'coord': '1828,880,97,21'},
#    'label': '',
#    'mag-year': 'dkm-1941'},
#   {'ent': {'lastname': 'Knöpfel',
#     'firstname': 'Johann Jacob',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Johann Jacob Knöpfel',
#     'profession': [],
#     'places': ['Urnäsch'],
#     'page': 'dkm-001_1941_001_0433.txt',
#     'year': '1941',
#     'coord': '1347,915,75,22'},
#    'label': '',
#    'mag-year': 'dkm-1941'},
#   {'ent': {'lastname': 'Knöpfel',
#     'firstname': 'Johann Jacob',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Johann Jacob Knöpfel',
#     'profession': [],
#     'places': ['Urnäsch'],
#     'page': 'dkm-001_1941_001_0433.txt',
#     'year': '1941',
#     'coord': '1436,915,105,28'},
#    'label': '',
#    'mag-year': 'dkm-1941'}],
#  [{'ent': {'lastname': 'Laemmel',
#     'firstname': 'Hans',
#     'abbr_firstname': ['Hs.'],
#     'other': [],
#     'name': 'Hans Laemmel',
#     'profession': [],
#     'places': ['Zürichsees'],
#     'page': 'dkm-001_1941_001_0442.txt',
#     'year': '1941',
#     'coord': '1901,2771,69,21'},
#    'label': '1156574803',
#    'mag-year': 'dkm-1941'},
#   {'ent': {'lastname': 'Laemmel',
#     'firstname': 'Hans',
#     'abbr_firstname': ['Hs.'],
#     'other': [],
#     'name': 'Hans Laemmel',
#     'profession': [],
#     'places': ['Zürichsees'],
#     'page': 'dkm-001_1941_001_0442.txt',
#     'year': '1941',
#     'coord': '1981,2770,116,21'},
#    'label': '1156574803',
#    'mag-year': 'dkm-1941'}],
#  [{'ent': {'lastname': 'Law',
#     'firstname': 'Ernst',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Ernst Law',
#     'profession': ['Dr.'],
#     'places': ['Basel'],
#     'page': 'dkm-001_1941_001_0434.txt',
#     'year': '1941',
#     'coord': '1431,1732,71,21'},
#    'label': '119202220',
#    'mag-year': 'dkm-1941'},
#   {'ent': {'lastname': 'Law',
#     'firstname': 'Ernst',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Ernst Law',
#     'profession': ['Dr.'],
#     'places': ['Basel'],
#     'page': 'dkm-001_1941_001_0434.txt',
#     'year': '1941',
#     'coord': '1377,1731,41,22'},
#    'label': '119202220',
#    'mag-year': 'dkm-1941'},
#   {'ent': {'lastname': 'Law',
#     'firstname': 'Ernst',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Ernst Law',
#     'profession': ['Dr.'],
#     'places': ['Basel'],
#     'page': 'dkm-001_1941_001_0434.txt',
#     'year': '1941',
#     'coord': '1512,1732,64,21'},
#    'label': '119202220',
#    'mag-year': 'dkm-1941'}],
#  [{'ent': {'lastname': 'Lämmler',
#     'firstname': 'Bartholome',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Bartholome Lämmler',
#     'profession': [],
#     'places': ['Hundwil'],
#     'page': 'dkm-001_1941_001_0431.txt',
#     'year': '1941',
#     'coord': '1189,2739,120,23'},
#    'label': '121498166',
#    'mag-year': 'dkm-1941'},
#   {'ent': {'lastname': 'Lämmler',
#     'firstname': 'Bartholome',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Bartholome Lämmler',
#     'profession': [],
#     'places': ['Hundwil'],
#     'page': 'dkm-001_1941_001_0431.txt',
#     'year': '1941',
#     'coord': '1019,2740,158,21'},
#    'label': '121498166',
#    'mag-year': 'dkm-1941'}],
#  [{'ent': {'lastname': 'Mock',
#     'firstname': 'Hastöni',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Hastöni Mock',
#     'profession': [],
#     'places': ['Appenzell'],
#     'page': 'dkm-001_1941_001_0442.txt',
#     'year': '1941',
#     'coord': '1241,1270,103,21'},
#    'label': '',
#    'mag-year': 'dkm-1941'},
#   {'ent': {'lastname': 'Mock',
#     'firstname': 'Hastöni',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Hastöni Mock',
#     'profession': [],
#     'places': ['Appenzell'],
#     'page': 'dkm-001_1941_001_0442.txt',
#     'year': '1941',
#     'coord': '1362,1270,69,21'},
#    'label': '',
#    'mag-year': 'dkm-1941'},
#   {'ent': {'lastname': 'Mock',
#     'firstname': 'Hastöni',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Hastöni Mock',
#     'profession': [],
#     'places': ['Appenzell'],
#     'page': 'dkm-001_1941_001_0442.txt',
#     'year': '1941',
#     'coord': '1603,2094,68,21'},
#    'label': '',
#    'mag-year': 'dkm-1941'},
#   {'ent': {'lastname': 'Mock',
#     'firstname': 'Hastöni',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Hastöni Mock',
#     'profession': [],
#     'places': ['Appenzell'],
#     'page': 'dkm-001_1941_001_0442.txt',
#     'year': '1941',
#     'coord': '1480,2095,102,20'},
#    'label': '',
#    'mag-year': 'dkm-1941'},
#   {'ent': {'lastname': 'Mock',
#     'firstname': 'Hastöni',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Hastöni Mock',
#     'profession': [],
#     'places': ['Appenzell'],
#     'page': 'dkm-001_1941_001_0442.txt',
#     'year': '1941',
#     'coord': '1432,1306,79,21'},
#    'label': '',
#    'mag-year': 'dkm-1941'},
#   {'ent': {'lastname': 'Mock',
#     'firstname': 'Hastöni',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Hastöni Mock',
#     'profession': [],
#     'places': ['Appenzell'],
#     'page': 'dkm-001_1941_001_0442.txt',
#     'year': '1941',
#     'coord': '1944,2129,68,21'},
#    'label': '',
#    'mag-year': 'dkm-1941'}],
#  [{'ent': {'lastname': 'Müller',
#     'firstname': 'Johannes',
#     'abbr_firstname': [],
#     'other': [['Herr', 'von', 'Oldenburg-J', 'a'], ['von']],
#     'name': 'Johannes Müller',
#     'profession': [],
#     'places': ['Hundwil', 'Nusehau'],
#     'page': 'dkm-001_1941_001_0431.txt',
#     'year': '1941',
#     'coord': '760,2775,84,21'},
#    'label': '135803985',
#    'mag-year': 'dkm-1941'},
#   {'ent': {'lastname': 'Müller',
#     'firstname': 'Johannes',
#     'abbr_firstname': [],
#     'other': [['Herr', 'von', 'Oldenburg-J', 'a'], ['von']],
#     'name': 'Johannes Müller',
#     'profession': [],
#     'places': ['Hundwil', 'Nusehau'],
#     'page': 'dkm-001_1941_001_0431.txt',
#     'year': '1941',
#     'coord': '624,2775,123,21'},
#    'label': '135803985',
#    'mag-year': 'dkm-1941'}],
#  [{'ent': {'lastname': 'Nievergelt',
#     'firstname': 'Olga',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Olga Nievergelt',
#     'profession': [],
#     'places': ['Zürich'],
#     'page': 'dkm-001_1941_001_0439.txt',
#     'year': '1941',
#     'coord': '1982,2746,109,22'},
#    'label': '',
#    'mag-year': 'dkm-1941'},
#   {'ent': {'lastname': 'Nievergelt',
#     'firstname': 'Olga',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Olga Nievergelt',
#     'profession': [],
#     'places': ['Zürich'],
#     'page': 'dkm-001_1941_001_0439.txt',
#     'year': '1941',
#     'coord': '1925,2745,49,23'},
#    'label': '',
#    'mag-year': 'dkm-1941'},
#   {'ent': {'lastname': 'Nievergelt',
#     'firstname': 'Olga',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Olga Nievergelt',
#     'profession': [],
#     'places': ['Zürich'],
#     'page': 'dkm-001_1941_001_0440.txt',
#     'year': '1941',
#     'coord': '207,784,143,28'},
#    'label': '',
#    'mag-year': 'dkm-1941'},
#   {'ent': {'lastname': 'Nievergelt',
#     'firstname': 'Olga',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Olga Nievergelt',
#     'profession': [],
#     'places': ['Zürich'],
#     'page': 'dkm-001_1941_001_0440.txt',
#     'year': '1941',
#     'coord': '126,785,59,27'},
#    'label': '',
#    'mag-year': 'dkm-1941'},
#   {'ent': {'lastname': 'Nievergelt',
#     'firstname': 'Olga',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Olga Nievergelt',
#     'profession': [],
#     'places': ['Zürich'],
#     'page': 'dkm-001_1941_001_0440.txt',
#     'year': '1941',
#     'coord': '669,750,61,20'},
#    'label': '',
#    'mag-year': 'dkm-1941'}],
#  [{'ent': {'lastname': 'Sutter',
#     'firstname': 'Marie',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Marie Sutter',
#     'profession': [],
#     'places': ['Zürich', 'Schweiz', 'Appenzell', 'London'],
#     'page': 'dkm-001_1941_001_0442.txt',
#     'year': '1941',
#     'coord': '294,554,89,27'},
#    'label': '',
#    'mag-year': 'dkm-1941'},
#   {'ent': {'lastname': 'Sutter',
#     'firstname': 'Marie',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Marie Sutter',
#     'profession': [],
#     'places': ['Zürich', 'Schweiz', 'Appenzell', 'London'],
#     'page': 'dkm-001_1941_001_0442.txt',
#     'year': '1941',
#     'coord': '205,554,73,22'},
#    'label': '',
#    'mag-year': 'dkm-1941'},
#   {'ent': {'lastname': 'Sutter',
#     'firstname': 'Marie',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Marie Sutter',
#     'profession': [],
#     'places': ['Zürich', 'Schweiz', 'Appenzell', 'London'],
#     'page': 'dkm-001_1941_001_0442.txt',
#     'year': '1941',
#     'coord': '1847,2199,88,26'},
#    'label': '',
#    'mag-year': 'dkm-1941'},
#   {'ent': {'lastname': 'Sutter',
#     'firstname': 'Marie',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Marie Sutter',
#     'profession': [],
#     'places': ['Zürich', 'Schweiz', 'Appenzell', 'London'],
#     'page': 'dkm-001_1941_001_0442.txt',
#     'year': '1941',
#     'coord': '1753,2200,72,21'},
#    'label': '',
#    'mag-year': 'dkm-1941'},
#   {'ent': {'lastname': 'Sutter',
#     'firstname': 'Marie',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Marie Sutter',
#     'profession': [],
#     'places': ['Zürich', 'Schweiz', 'Appenzell', 'London'],
#     'page': 'dkm-001_1941_001_0442.txt',
#     'year': '1941',
#     'coord': '713,2066,72,21'},
#    'label': '',
#    'mag-year': 'dkm-1941'},
#   {'ent': {'lastname': 'Sutter',
#     'firstname': 'Marie',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Marie Sutter',
#     'profession': [],
#     'places': ['Zürich', 'Schweiz', 'Appenzell', 'London'],
#     'page': 'dkm-001_1941_001_0443.txt',
#     'year': '1941',
#     'coord': '1030,2338,90,22'},
#    'label': '',
#    'mag-year': 'dkm-1941'},
#   {'ent': {'lastname': 'Sutter',
#     'firstname': 'Marie',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Marie Sutter',
#     'profession': [],
#     'places': ['Zürich', 'Schweiz', 'Appenzell', 'London'],
#     'page': 'dkm-001_1941_001_0443.txt',
#     'year': '1941',
#     'coord': '945,2338,72,22'},
#    'label': '',
#    'mag-year': 'dkm-1941'},
#   {'ent': {'lastname': 'Sutter',
#     'firstname': 'Marie',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Marie Sutter',
#     'profession': [],
#     'places': ['Zürich', 'Schweiz', 'Appenzell', 'London'],
#     'page': 'dkm-001_1941_001_0443.txt',
#     'year': '1941',
#     'coord': '907,2373,72,22'},
#    'label': '',
#    'mag-year': 'dkm-1941'},
#   {'ent': {'lastname': 'Sutter',
#     'firstname': 'Marie',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Marie Sutter',
#     'profession': [],
#     'places': ['Zürich', 'Schweiz', 'Appenzell', 'London'],
#     'page': 'dkm-001_1941_001_0443.txt',
#     'year': '1941',
#     'coord': '905,2410,72,21'},
#    'label': '',
#    'mag-year': 'dkm-1941'}],
#  [{'ent': {'lastname': 'Weiß',
#     'firstname': 'Manfred',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Manfred Weiß',
#     'profession': [],
#     'places': ['Brugg'],
#     'page': 'dkm-001_1941_001_0441.txt',
#     'year': '1941',
#     'coord': '1936,2773,96,21'},
#    'label': '',
#    'mag-year': 'dkm-1941'},
#   {'ent': {'lastname': 'Weiß',
#     'firstname': 'Manfred',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Manfred Weiß',
#     'profession': [],
#     'places': ['Brugg'],
#     'page': 'dkm-001_1941_001_0441.txt',
#     'year': '1941',
#     'coord': '2040,2774,59,20'},
#    'label': '',
#    'mag-year': 'dkm-1941'}],
#  [{'ent': {'lastname': 'Zolle',
#     'firstname': 'Johannes',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Johannes Zolle',
#     'profession': [],
#     'places': ['Ostschweiz'],
#     'page': 'dkm-001_1941_001_0427.txt',
#     'year': '1941',
#     'coord': '1801,1710,110,26'},
#    'label': '107217720X',
#    'mag-year': 'dkm-1941'},
#   {'ent': {'lastname': 'Zolle',
#     'firstname': 'Johannes',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Johannes Zolle',
#     'profession': [],
#     'places': ['Ostschweiz'],
#     'page': 'dkm-001_1941_001_0427.txt',
#     'year': '1941',
#     'coord': '1599,1715,184,22'},
#    'label': '107217720X',
#    'mag-year': 'dkm-1941'}],
#  [{'ent': {'lastname': 'Zeller',
#     'firstname': 'Johann Baptist',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Johann Baptist Zeller',
#     'profession': [],
#     'places': ['Appenzell'],
#     'page': 'dkm-001_1941_001_0429.txt',
#     'year': '1941',
#     'coord': '1264,296,81,22'},
#    'label': '1046849964',
#    'mag-year': 'dkm-1941'},
#   {'ent': {'lastname': 'Zeller',
#     'firstname': 'Johann Baptist',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Johann Baptist Zeller',
#     'profession': [],
#     'places': ['Appenzell'],
#     'page': 'dkm-001_1941_001_0429.txt',
#     'year': '1941',
#     'coord': '1041,295,99,23'},
#    'label': '1046849964',
#    'mag-year': 'dkm-1941'},
#   {'ent': {'lastname': 'Zeller',
#     'firstname': 'Johann Baptist',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Johann Baptist Zeller',
#     'profession': [],
#     'places': ['Appenzell'],
#     'page': 'dkm-001_1941_001_0429.txt',
#     'year': '1941',
#     'coord': '1154,296,96,28'},
#    'label': '1046849964',
#    'mag-year': 'dkm-1941'}],
#  [{'ent': {'lastname': '',
#     'firstname': 'Alice',
#     'abbr_firstname': [],
#     'other': [],
#     'name': None,
#     'profession': [],
#     'places': ['Ch'],
#     'page': 'dkm-003_2010_070_0052.txt',
#     'year': '2010',
#     'coord': '1780,1256,68,23'},
#    'label': '',
#    'mag-year': 'dkm-2010'}],
#  [{'ent': {'lastname': '',
#     'firstname': 'Marc',
#     'abbr_firstname': [],
#     'other': [['|', 'Gleizes']],
#     'name': None,
#     'profession': [],
#     'places': ['Toulouse-Lautrec', 'Kalvach', 'Zug', 'Zugersee'],
#     'page': 'dkm-003_2010_070_0043.txt',
#     'year': '2010',
#     'coord': '1662,2393,61,19'},
#    'label': '',
#    'mag-year': 'dkm-2010'},
#   {'ent': {'lastname': '',
#     'firstname': 'Marc',
#     'abbr_firstname': [],
#     'other': [['|', 'Gleizes']],
#     'name': None,
#     'profession': [],
#     'places': ['Toulouse-Lautrec', 'Kalvach', 'Zug', 'Zugersee'],
#     'page': 'dkm-003_2010_070_0043.txt',
#     'year': '2010',
#     'coord': '1748,2391,90,21'},
#    'label': '',
#    'mag-year': 'dkm-2010'}],
#  [{'ent': {'lastname': '',
#     'firstname': 'Ulla',
#     'abbr_firstname': [],
#     'other': [],
#     'name': None,
#     'profession': [],
#     'places': ['Zürich', 'Unselds', 'Frankfurt'],
#     'page': 'dkm-003_2010_070_0051.txt',
#     'year': '2010',
#     'coord': '764,362,184,88'},
#    'label': '119150026',
#    'mag-year': 'dkm-2010'}],
#  [{'ent': {'lastname': '',
#     'firstname': 'Brecht',
#     'abbr_firstname': [],
#     'other': [],
#     'name': None,
#     'profession': [],
#     'places': ['Unselds'],
#     'page': 'dkm-003_2010_070_0051.txt',
#     'year': '2010',
#     'coord': '156,2309,99,30'},
#    'label': '118514768',
#    'mag-year': 'dkm-2010'}],
#  [{'ent': {'lastname': '',
#     'firstname': '',
#     'abbr_firstname': [],
#     'other': [['Suhrkamp']],
#     'name': 'Suhrkamp',
#     'profession': [],
#     'places': ['Welt', 'Usa', 'Chui'],
#     'page': 'dkm-003_2010_070_0043.txt',
#     'year': '2010',
#     'coord': '228,713,139,33'},
#    'label': '118619977',
#    'mag-year': 'dkm-2010'},
#   {'ent': {'lastname': '',
#     'firstname': '',
#     'abbr_firstname': [],
#     'other': [['Suhrkamp']],
#     'name': 'Suhrkamp',
#     'profession': [],
#     'places': ['Welt', 'Usa', 'Chui'],
#     'page': 'dkm-003_2010_070_0047.txt',
#     'year': '2010',
#     'coord': '215,1875,150,34'},
#    'label': '118619977',
#    'mag-year': 'dkm-2010'},
#   {'ent': {'lastname': '',
#     'firstname': '',
#     'abbr_firstname': [],
#     'other': [['Suhrkamp']],
#     'name': 'Suhrkamp',
#     'profession': [],
#     'places': ['Welt', 'Usa', 'Chui'],
#     'page': 'dkm-003_2010_070_0048.txt',
#     'year': '2010',
#     'coord': '1953,1220,151,34'},
#    'label': '118619977',
#    'mag-year': 'dkm-2010'},
#   {'ent': {'lastname': '',
#     'firstname': '',
#     'abbr_firstname': [],
#     'other': [['Suhrkamp']],
#     'name': 'Suhrkamp',
#     'profession': [],
#     'places': ['Welt', 'Usa', 'Chui'],
#     'page': 'dkm-003_2010_070_0051.txt',
#     'year': '2010',
#     'coord': '416,1156,150,34'},
#    'label': '118619977',
#    'mag-year': 'dkm-2010'},
#   {'ent': {'lastname': '',
#     'firstname': '',
#     'abbr_firstname': [],
#     'other': [['Suhrkamp']],
#     'name': 'Suhrkamp',
#     'profession': [],
#     'places': ['Welt', 'Usa', 'Chui'],
#     'page': 'dkm-003_2010_070_0051.txt',
#     'year': '2010',
#     'coord': '1587,1358,150,34'},
#    'label': '118619977',
#    'mag-year': 'dkm-2010'},
#   {'ent': {'lastname': '',
#     'firstname': '',
#     'abbr_firstname': [],
#     'other': [['Suhrkamp']],
#     'name': 'Suhrkamp',
#     'profession': [],
#     'places': ['Welt', 'Usa', 'Chui'],
#     'page': 'dkm-003_2010_070_0052.txt',
#     'year': '2010',
#     'coord': '1210,2005,79,34'},
#    'label': '118619977',
#    'mag-year': 'dkm-2010'},
#   {'ent': {'lastname': '',
#     'firstname': '',
#     'abbr_firstname': [],
#     'other': [['Suhrkamp']],
#     'name': 'Suhrkamp',
#     'profession': [],
#     'places': ['Welt', 'Usa', 'Chui'],
#     'page': 'dkm-003_2010_070_0052.txt',
#     'year': '2010',
#     'coord': '2063,1954,93,26'},
#    'label': '118619977',
#    'mag-year': 'dkm-2010'},
#   {'ent': {'lastname': '',
#     'firstname': '',
#     'abbr_firstname': [],
#     'other': [['Suhrkamp']],
#     'name': 'Suhrkamp',
#     'profession': [],
#     'places': ['Welt', 'Usa', 'Chui'],
#     'page': 'dkm-003_2010_070_0057.txt',
#     'year': '2010',
#     'coord': '315,612,185,45'},
#    'label': '118619977',
#    'mag-year': 'dkm-2010'}],
#  [{'ent': {'lastname': '',
#     'firstname': '',
#     'abbr_firstname': [],
#     'other': [['Fleckhaus']],
#     'name': 'Fleckhaus',
#     'profession': [],
#     'places': ['Deutschland',
#      'Fiankfurt',
#      'Hambuig',
#      'Toulouse-Lautrec',
#      'Kalvach',
#      'Velbert',
#      'Madrid',
#      'Zug',
#      'München',
#      'Zugersee'],
#     'page': 'dkm-003_2010_070_0043.txt',
#     'year': '2010',
#     'coord': '744,1564,142,25'},
#    'label': '119520605',
#    'mag-year': 'dkm-2010'},
#   {'ent': {'lastname': '',
#     'firstname': '',
#     'abbr_firstname': [],
#     'other': [['Fleckhaus']],
#     'name': 'Fleckhaus',
#     'profession': [],
#     'places': ['Deutschland',
#      'Fiankfurt',
#      'Hambuig',
#      'Toulouse-Lautrec',
#      'Kalvach',
#      'Velbert',
#      'Madrid',
#      'Zug',
#      'München',
#      'Zugersee'],
#     'page': 'dkm-003_2010_070_0043.txt',
#     'year': '2010',
#     'coord': '159,1763,63,26'},
#    'label': '119520605',
#    'mag-year': 'dkm-2010'},
#   {'ent': {'lastname': '',
#     'firstname': '',
#     'abbr_firstname': [],
#     'other': [['Fleckhaus']],
#     'name': 'Fleckhaus',
#     'profession': [],
#     'places': ['Deutschland',
#      'Fiankfurt',
#      'Hambuig',
#      'Toulouse-Lautrec',
#      'Kalvach',
#      'Velbert',
#      'Madrid',
#      'Zug',
#      'München',
#      'Zugersee'],
#     'page': 'dkm-003_2010_070_0043.txt',
#     'year': '2010',
#     'coord': '1019,1715,88,25'},
#    'label': '119520605',
#    'mag-year': 'dkm-2010'}],
#  [{'ent': {'lastname': '',
#     'firstname': '',
#     'abbr_firstname': [],
#     'other': [['Kokoschka']],
#     'name': 'Kokoschka',
#     'profession': [],
#     'places': ['Toulouse-Lautrec', 'Kalvach', 'Zug', 'Zugersee'],
#     'page': 'dkm-003_2010_070_0043.txt',
#     'year': '2010',
#     'coord': '1916,2327,132,22'},
#    'label': '',
#    'mag-year': 'dkm-2010'}],
#  [{'ent': {'lastname': '',
#     'firstname': '',
#     'abbr_firstname': [],
#     'other': [['Dix']],
#     'name': 'Dix',
#     'profession': [],
#     'places': ['Toulouse-Lautrec', 'Kalvach', 'Zug', 'Zugersee'],
#     'page': 'dkm-003_2010_070_0043.txt',
#     'year': '2010',
#     'coord': '1764,2361,42,19'},
#    'label': '',
#    'mag-year': 'dkm-2010'}],
#  [{'ent': {'lastname': '',
#     'firstname': '',
#     'abbr_firstname': [],
#     'other': [['Klee']],
#     'name': 'Klee',
#     'profession': [],
#     'places': ['Toulouse-Lautrec', 'Kalvach', 'Zug', 'Zugersee'],
#     'page': 'dkm-003_2010_070_0043.txt',
#     'year': '2010',
#     'coord': '1467,2391,52,21'},
#    'label': '118562827',
#    'mag-year': 'dkm-2010'}],
#  [{'ent': {'lastname': '',
#     'firstname': '',
#     'abbr_firstname': [],
#     'other': [['Villon']],
#     'name': 'Villon',
#     'profession': [],
#     'places': ['Toulouse-Lautrec', 'Kalvach', 'Zug', 'Zugersee'],
#     'page': 'dkm-003_2010_070_0043.txt',
#     'year': '2010',
#     'coord': '1518,2422,74,21'},
#    'label': '',
#    'mag-year': 'dkm-2010'}],
#  [{'ent': {'lastname': '',
#     'firstname': '',
#     'abbr_firstname': [],
#     'other': [['Pooya', 'Aryanpour']],
#     'name': 'Pooya Aryanpour',
#     'profession': [],
#     'places': ['Deutschland',
#      'Emmenbrücke-Luzern',
#      'Frankfurt',
#      'Alexandria'],
#     'page': 'dkm-003_2010_070_0046.txt',
#     'year': '2010',
#     'coord': '605,2743,89,32'},
#    'label': '',
#    'mag-year': 'dkm-2010'},
#   {'ent': {'lastname': '',
#     'firstname': '',
#     'abbr_firstname': [],
#     'other': [['Pooya', 'Aryanpour']],
#     'name': 'Pooya Aryanpour',
#     'profession': [],
#     'places': ['Deutschland',
#      'Emmenbrücke-Luzern',
#      'Frankfurt',
#      'Alexandria'],
#     'page': 'dkm-003_2010_070_0046.txt',
#     'year': '2010',
#     'coord': '704,2743,159,32'},
#    'label': '',
#    'mag-year': 'dkm-2010'}],
#  [{'ent': {'lastname': '',
#     'firstname': '',
#     'abbr_firstname': [],
#     'other': [['Fereydoun']],
#     'name': 'Fereydoun',
#     'profession': [],
#     'places': ['Deutschland',
#      'Emmenbrücke-Luzern',
#      'Frankfurt',
#      'Alexandria'],
#     'page': 'dkm-003_2010_070_0046.txt',
#     'year': '2010',
#     'coord': '1145,2742,154,33'},
#    'label': '1135995109',
#    'mag-year': 'dkm-2010'}],
#  [{'ent': {'lastname': '',
#     'firstname': '',
#     'abbr_firstname': [],
#     'other': [['Durs', 'Grünbein']],
#     'name': 'Durs Grünbein',
#     'profession': [],
#     'places': ['Südamerikas', 'Unselds', 'Laos'],
#     'page': 'dkm-003_2010_070_0052.txt',
#     'year': '2010',
#     'coord': '202,605,146,32'},
#    'label': '119371391',
#    'mag-year': 'dkm-2010'},
#   {'ent': {'lastname': '',
#     'firstname': '',
#     'abbr_firstname': [],
#     'other': [['Durs', 'Grünbein']],
#     'name': 'Durs Grünbein',
#     'profession': [],
#     'places': ['Südamerikas', 'Unselds', 'Laos'],
#     'page': 'dkm-003_2010_070_0052.txt',
#     'year': '2010',
#     'coord': '1080,555,69,25'},
#    'label': '119371391',
#    'mag-year': 'dkm-2010'}],
#  [{'ent': {'lastname': '',
#     'firstname': '',
#     'abbr_firstname': [],
#     'other': [['ndrRs', 'Heller']],
#     'name': 'ndrRs Heller',
#     'profession': [],
#     'places': ['Schweiz'],
#     'page': 'dkm-003_2010_070_0055.txt',
#     'year': '2010',
#     'coord': '1192,2406,69,21'},
#    'label': '',
#    'mag-year': 'dkm-2010'}],
#  [{'ent': {'lastname': 'Ahmadi',
#     'firstname': 'Shahriar',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Shahriar Ahmadi',
#     'profession': [],
#     'places': ['Deutschland',
#      'Emmenbrücke-Luzern',
#      'Frankfurt',
#      'Alexandria'],
#     'page': 'dkm-003_2010_070_0046.txt',
#     'year': '2010',
#     'coord': '490,2698,128,27'},
#    'label': '138939373',
#    'mag-year': 'dkm-2010'},
#   {'ent': {'lastname': 'Ahmadi',
#     'firstname': 'Shahriar',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Shahriar Ahmadi',
#     'profession': [],
#     'places': ['Deutschland',
#      'Emmenbrücke-Luzern',
#      'Frankfurt',
#      'Alexandria'],
#     'page': 'dkm-003_2010_070_0046.txt',
#     'year': '2010',
#     'coord': '627,2698,114,27'},
#    'label': '138939373',
#    'mag-year': 'dkm-2010'}],
#  [{'ent': {'lastname': 'Ahrend',
#     'firstname': 'Thorsten',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Thorsten Ahrend',
#     'profession': [],
#     'places': ['Wallstein'],
#     'page': 'dkm-003_2010_070_0048.txt',
#     'year': '2010',
#     'coord': '472,2769,118,31'},
#    'label': '111865182',
#    'mag-year': 'dkm-2010'},
#   {'ent': {'lastname': 'Ahrend',
#     'firstname': 'Thorsten',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Thorsten Ahrend',
#     'profession': [],
#     'places': ['Wallstein'],
#     'page': 'dkm-003_2010_070_0048.txt',
#     'year': '2010',
#     'coord': '323,2769,128,26'},
#    'label': '111865182',
#    'mag-year': 'dkm-2010'}],
#  [{'ent': {'lastname': 'Ammann',
#     'firstname': 'Egon',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Egon Ammann',
#     'profession': [],
#     'places': ['Zürich', 'Bern', 'Frankreich', 'Schweiz'],
#     'page': 'dkm-003_2010_070_0057.txt',
#     'year': '2010',
#     'coord': '378,533,171,32'},
#    'label': '10906769X',
#    'mag-year': 'dkm-2010'},
#   {'ent': {'lastname': 'Ammann',
#     'firstname': 'Egon',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Egon Ammann',
#     'profession': [],
#     'places': ['Zürich', 'Bern', 'Frankreich', 'Schweiz'],
#     'page': 'dkm-003_2010_070_0057.txt',
#     'year': '2010',
#     'coord': '274,533,92,43'},
#    'label': '10906769X',
#    'mag-year': 'dkm-2010'},
#   {'ent': {'lastname': 'Ammann',
#     'firstname': 'Egon',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Egon Ammann',
#     'profession': [],
#     'places': ['Zürich', 'Bern', 'Frankreich', 'Schweiz'],
#     'page': 'dkm-003_2010_070_0057.txt',
#     'year': '2010',
#     'coord': '618,897,78,36'},
#    'label': '10906769X',
#    'mag-year': 'dkm-2010'},
#   {'ent': {'lastname': 'Ammann',
#     'firstname': 'Egon',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Egon Ammann',
#     'profession': [],
#     'places': ['Zürich', 'Bern', 'Frankreich', 'Schweiz'],
#     'page': 'dkm-003_2010_070_0057.txt',
#     'year': '2010',
#     'coord': '705,896,145,27'},
#    'label': '10906769X',
#    'mag-year': 'dkm-2010'},
#   {'ent': {'lastname': 'Ammann',
#     'firstname': 'Egon',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Egon Ammann',
#     'profession': [],
#     'places': ['Zürich', 'Bern', 'Frankreich', 'Schweiz'],
#     'page': 'dkm-003_2010_070_0057.txt',
#     'year': '2010',
#     'coord': '227,2958,111,24'},
#    'label': '10906769X',
#    'mag-year': 'dkm-2010'},
#   {'ent': {'lastname': 'Ammann',
#     'firstname': 'Egon',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Egon Ammann',
#     'profession': [],
#     'places': ['Zürich', 'Bern', 'Frankreich', 'Schweiz'],
#     'page': 'dkm-003_2010_070_0057.txt',
#     'year': '2010',
#     'coord': '163,2958,54,27'},
#    'label': '10906769X',
#    'mag-year': 'dkm-2010'},
#   {'ent': {'lastname': 'Ammann',
#     'firstname': 'Egon',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Egon Ammann',
#     'profession': [],
#     'places': ['Zürich', 'Bern', 'Frankreich', 'Schweiz'],
#     'page': 'dkm-003_2010_070_0057.txt',
#     'year': '2010',
#     'coord': '1068,696,172,32'},
#    'label': '10906769X',
#    'mag-year': 'dkm-2010'},
#   {'ent': {'lastname': 'Ammann',
#     'firstname': 'Egon',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Egon Ammann',
#     'profession': [],
#     'places': ['Zürich', 'Bern', 'Frankreich', 'Schweiz'],
#     'page': 'dkm-003_2010_070_0059.txt',
#     'year': '2010',
#     'coord': '1229,2536,114,23'},
#    'label': '10906769X',
#    'mag-year': 'dkm-2010'},
#   {'ent': {'lastname': 'Ammann',
#     'firstname': 'Egon',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Egon Ammann',
#     'profession': [],
#     'places': ['Zürich', 'Bern', 'Frankreich', 'Schweiz'],
#     'page': 'dkm-003_2010_070_0059.txt',
#     'year': '2010',
#     'coord': '1162,2536,58,26'},
#    'label': '10906769X',
#    'mag-year': 'dkm-2010'},
#   {'ent': {'lastname': 'Ammann',
#     'firstname': 'Egon',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Egon Ammann',
#     'profession': [],
#     'places': ['Zürich', 'Bern', 'Frankreich', 'Schweiz'],
#     'page': 'dkm-003_2010_070_0059.txt',
#     'year': '2010',
#     'coord': '1632,2651,106,20'},
#    'label': '10906769X',
#    'mag-year': 'dkm-2010'},
#   {'ent': {'lastname': 'Ammann',
#     'firstname': 'Egon',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Egon Ammann',
#     'profession': [],
#     'places': ['Zürich', 'Bern', 'Frankreich', 'Schweiz'],
#     'page': 'dkm-003_2010_070_0059.txt',
#     'year': '2010',
#     'coord': '1322,2690,105,20'},
#    'label': '10906769X',
#    'mag-year': 'dkm-2010'}],
#  [{'ent': {'lastname': 'Azadeh',
#     'firstname': '',
#     'abbr_firstname': [],
#     'other': [],
#     'name': None,
#     'profession': [],
#     'places': ['Deutschland',
#      'Emmenbrücke-Luzern',
#      'Frankfurt',
#      'Alexandria'],
#     'page': 'dkm-003_2010_070_0046.txt',
#     'year': '2010',
#     'coord': '257,2742,109,26'},
#    'label': '138937818',
#    'mag-year': 'dkm-2010'}],
#  [{'ent': {'lastname': 'Barlach',
#     'firstname': 'Hans',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Hans Barlach',
#     'profession': [],
#     'places': ['Winterthur', 'München'],
#     'page': 'dkm-003_2010_070_0048.txt',
#     'year': '2010',
#     'coord': '1353,2120,113,29'},
#    'label': '1045755834',
#    'mag-year': 'dkm-2010'},
#   {'ent': {'lastname': 'Barlach',
#     'firstname': 'Hans',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Hans Barlach',
#     'profession': [],
#     'places': ['Winterthur', 'München'],
#     'page': 'dkm-003_2010_070_0048.txt',
#     'year': '2010',
#     'coord': '1257,2121,76,24'},
#    'label': '1045755834',
#    'mag-year': 'dkm-2010'},
#   {'ent': {'lastname': 'Barlach',
#     'firstname': 'Hans',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Hans Barlach',
#     'profession': [],
#     'places': ['Winterthur', 'München'],
#     'page': 'dkm-003_2010_070_0048.txt',
#     'year': '2010',
#     'coord': '1611,2370,104,24'},
#    'label': '1045755834',
#    'mag-year': 'dkm-2010'},
#   {'ent': {'lastname': 'Barlach',
#     'firstname': 'Hans',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Hans Barlach',
#     'profession': [],
#     'places': ['Winterthur', 'München'],
#     'page': 'dkm-003_2010_070_0049.txt',
#     'year': '2010',
#     'coord': '1500,2375,74,24'},
#    'label': '1045755834',
#    'mag-year': 'dkm-2010'},
#   {'ent': {'lastname': 'Barlach',
#     'firstname': 'Hans',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Hans Barlach',
#     'profession': [],
#     'places': ['Winterthur', 'München'],
#     'page': 'dkm-003_2010_070_0049.txt',
#     'year': '2010',
#     'coord': '1588,2373,103,26'},
#    'label': '1045755834',
#    'mag-year': 'dkm-2010'}],
#  [{'ent': {'lastname': 'Barlach',
#     'firstname': 'Ernst',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Ernst Barlach',
#     'profession': ['Bildhauers', 'Und', 'Schriftsteller'],
#     'places': ['Welt', 'München', 'Göttingen', 'Köln', 'Wallstein'],
#     'page': 'dkm-003_2010_070_0048.txt',
#     'year': '2010',
#     'coord': '1962,2120,192,25'},
#    'label': '118506617',
#    'mag-year': 'dkm-2010'},
#   {'ent': {'lastname': 'Barlach',
#     'firstname': 'Ernst',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Ernst Barlach',
#     'profession': ['Bildhauers', 'Und', 'Schriftsteller'],
#     'places': ['Welt', 'München', 'Göttingen', 'Köln', 'Wallstein'],
#     'page': 'dkm-003_2010_070_0048.txt',
#     'year': '2010',
#     'coord': '1300,2170,113,25'},
#    'label': '118506617',
#    'mag-year': 'dkm-2010'},
#   {'ent': {'lastname': 'Barlach',
#     'firstname': 'Ernst',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Ernst Barlach',
#     'profession': ['Bildhauers', 'Und', 'Schriftsteller'],
#     'places': ['Welt', 'München', 'Göttingen', 'Köln', 'Wallstein'],
#     'page': 'dkm-003_2010_070_0048.txt',
#     'year': '2010',
#     'coord': '1206,2171,76,24'},
#    'label': '118506617',
#    'mag-year': 'dkm-2010'},
#   {'ent': {'lastname': 'Barlach',
#     'firstname': 'Ernst',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Ernst Barlach',
#     'profession': ['Bildhauers', 'Und', 'Schriftsteller'],
#     'places': ['Welt', 'München', 'Göttingen', 'Köln', 'Wallstein'],
#     'page': 'dkm-003_2010_070_0048.txt',
#     'year': '2010',
#     'coord': '1720,2120,149,25'},
#    'label': '118506617',
#    'mag-year': 'dkm-2010'}],
#  [{'ent': {'lastname': 'Beaumont',
#     'firstname': 'Yves',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Yves Beaumont',
#     'profession': [],
#     'places': ['Deutschland',
#      'Emmenbrücke-Luzern',
#      'Frankfurt',
#      'Alexandria'],
#     'page': 'dkm-003_2010_070_0046.txt',
#     'year': '2010',
#     'coord': '588,2786,152,25'},
#    'label': '143210319',
#    'mag-year': 'dkm-2010'},
#   {'ent': {'lastname': 'Beaumont',
#     'firstname': 'Yves',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Yves Beaumont',
#     'profession': [],
#     'places': ['Deutschland',
#      'Emmenbrücke-Luzern',
#      'Frankfurt',
#      'Alexandria'],
#     'page': 'dkm-003_2010_070_0046.txt',
#     'year': '2010',
#     'coord': '508,2786,66,25'},
#    'label': '143210319',
#    'mag-year': 'dkm-2010'}],
#  [{'ent': {'lastname': 'Beckett',
#     'firstname': '',
#     'abbr_firstname': [],
#     'other': [],
#     'name': None,
#     'profession': [],
#     'places': ['Spanien',
#      'Frankfurt',
# ...
#     'coord': '1097,2469,121,22'},
#    'label': '',
#    'mag-year': 'sbz-1895'}],
#  [{'ent': {'lastname': 'Helbling',
#     'firstname': '',
#     'abbr_firstname': ['R.', 'Rob.'],
#     'other': [],
#     'name': 'R. Rob. Helbling',
#     'profession': ['Dr.'],
#     'places': ['Rio Mendoza',
#      'Vacas',
#      'Ostalpen',
#      'Mendoza',
#      'De',
#      'Klebelsberg',
#      'Punta',
#      'Nevadogebiet',
#      'Rio'],
#     'page': 'sbz-002_1940_115_0215.txt',
#     'year': '1940',
#     'coord': '1704,708,131,26'},
#    'label': '1064992870',
#    'mag-year': 'sbz-1940'},
#   {'ent': {'lastname': 'Helbling',
#     'firstname': '',
#     'abbr_firstname': ['R.', 'Rob.'],
#     'other': [],
#     'name': 'R. Rob. Helbling',
#     'profession': ['Dr.'],
#     'places': ['Rio Mendoza',
#      'Vacas',
#      'Ostalpen',
#      'Mendoza',
#      'De',
#      'Klebelsberg',
#      'Punta',
#      'Nevadogebiet',
#      'Rio'],
#     'page': 'sbz-002_1940_115_0215.txt',
#     'year': '1940',
#     'coord': '1652,709,42,23'},
#    'label': '1064992870',
#    'mag-year': 'sbz-1940'},
#   {'ent': {'lastname': 'Helbling',
#     'firstname': '',
#     'abbr_firstname': ['R.', 'Rob.'],
#     'other': [],
#     'name': 'R. Rob. Helbling',
#     'profession': ['Dr.'],
#     'places': ['Rio Mendoza',
#      'Vacas',
#      'Ostalpen',
#      'Mendoza',
#      'De',
#      'Klebelsberg',
#      'Punta',
#      'Nevadogebiet',
#      'Rio'],
#     'page': 'sbz-002_1940_115_0215.txt',
#     'year': '1940',
#     'coord': '1770,2895,111,22'},
#    'label': '1064992870',
#    'mag-year': 'sbz-1940'},
#   {'ent': {'lastname': 'Helbling',
#     'firstname': '',
#     'abbr_firstname': ['R.', 'Rob.'],
#     'other': [],
#     'name': 'R. Rob. Helbling',
#     'profession': ['Dr.'],
#     'places': ['Rio Mendoza',
#      'Vacas',
#      'Ostalpen',
#      'Mendoza',
#      'De',
#      'Klebelsberg',
#      'Punta',
#      'Nevadogebiet',
#      'Rio'],
#     'page': 'sbz-002_1940_115_0215.txt',
#     'year': '1940',
#     'coord': '1687,2896,40,18'},
#    'label': '1064992870',
#    'mag-year': 'sbz-1940'},
#   {'ent': {'lastname': 'Helbling',
#     'firstname': '',
#     'abbr_firstname': ['R.', 'Rob.'],
#     'other': [],
#     'name': 'R. Rob. Helbling',
#     'profession': ['Dr.'],
#     'places': ['Rio Mendoza',
#      'Vacas',
#      'Ostalpen',
#      'Mendoza',
#      'De',
#      'Klebelsberg',
#      'Punta',
#      'Nevadogebiet',
#      'Rio'],
#     'page': 'sbz-002_1940_115_0215.txt',
#     'year': '1940',
#     'coord': '1737,2896,26,17'},
#    'label': '1064992870',
#    'mag-year': 'sbz-1940'}],
#  [{'ent': {'lastname': 'Bachmann',
#     'firstname': 'Jul',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Jul Bachmann',
#     'profession': [],
#     'places': ['Österreich',
#      'Irak',
#      'Japan',
#      'Kopenhagen',
#      'Athen',
#      'Paris',
#      'Belgien',
#      'Russland',
#      'Schweiz',
#      'Deutschland',
#      'Udssr',
#      'Ungarn',
#      'Usa',
#      'England',
#      'Eth',
#      'Finnland',
#      'Frankreich',
#      'Griechenland',
#      'Zürich'],
#     'page': 'sbz-002_1965_083_3176.txt',
#     'year': '1965',
#     'coord': '831,171,127,23'},
#    'label': '127008381',
#    'mag-year': 'sbz-1965'},
#   {'ent': {'lastname': 'Bachmann',
#     'firstname': 'Jul',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Jul Bachmann',
#     'profession': [],
#     'places': ['Österreich',
#      'Irak',
#      'Japan',
#      'Kopenhagen',
#      'Athen',
#      'Paris',
#      'Belgien',
#      'Russland',
#      'Schweiz',
#      'Deutschland',
#      'Udssr',
#      'Ungarn',
#      'Usa',
#      'England',
#      'Eth',
#      'Finnland',
#      'Frankreich',
#      'Griechenland',
#      'Zürich'],
#     'page': 'sbz-002_1965_083_3176.txt',
#     'year': '1965',
#     'coord': '783,172,39,22'},
#    'label': '127008381',
#    'mag-year': 'sbz-1965'}],
#  [{'ent': {'lastname': 'Doxiades',
#     'firstname': '',
#     'abbr_firstname': ['C.'],
#     'other': [],
#     'name': 'C. Doxiades',
#     'profession': [],
#     'places': ['Athen'],
#     'page': 'sbz-002_1965_083_3176.txt',
#     'year': '1965',
#     'coord': '216,421,28,22'},
#    'label': '116191112',
#    'mag-year': 'sbz-1965'},
#   {'ent': {'lastname': 'Doxiades',
#     'firstname': '',
#     'abbr_firstname': ['C.'],
#     'other': [],
#     'name': 'C. Doxiades',
#     'profession': [],
#     'places': ['Athen'],
#     'page': 'sbz-002_1965_083_3176.txt',
#     'year': '1965',
#     'coord': '252,420,119,23'},
#    'label': '116191112',
#    'mag-year': 'sbz-1965'}],
#  [{'ent': {'lastname': 'Dubuisson',
#     'firstname': 'Jean',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Jean Dubuisson',
#     'profession': [],
#     'places': ['Österreich',
#      'Irak',
#      'Japan',
#      'Finnland',
#      'Frankreich',
#      'Udssr',
#      'Usa'],
#     'page': 'sbz-002_1965_083_3176.txt',
#     'year': '1965',
#     'coord': '597,1207,57,22'},
#    'label': '119298848',
#    'mag-year': 'sbz-1965'},
#   {'ent': {'lastname': 'Dubuisson',
#     'firstname': 'Jean',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Jean Dubuisson',
#     'profession': [],
#     'places': ['Österreich',
#      'Irak',
#      'Japan',
#      'Finnland',
#      'Frankreich',
#      'Udssr',
#      'Usa'],
#     'page': 'sbz-002_1965_083_3176.txt',
#     'year': '1965',
#     'coord': '663,1205,142,26'},
#    'label': '119298848',
#    'mag-year': 'sbz-1965'}],
#  [{'ent': {'lastname': 'Dusart',
#     'firstname': 'Etienne',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Etienne Dusart',
#     'profession': [],
#     'places': ['Belgien', 'Zürich', 'Kopenhagen', 'Eth'],
#     'page': 'sbz-002_1965_083_3176.txt',
#     'year': '1965',
#     'coord': '88,1834,97,22'},
#    'label': '',
#    'mag-year': 'sbz-1965'},
#   {'ent': {'lastname': 'Dusart',
#     'firstname': 'Etienne',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Etienne Dusart',
#     'profession': [],
#     'places': ['Belgien', 'Zürich', 'Kopenhagen', 'Eth'],
#     'page': 'sbz-002_1965_083_3176.txt',
#     'year': '1965',
#     'coord': '194,1835,88,21'},
#    'label': '',
#    'mag-year': 'sbz-1965'}],
#  [{'ent': {'lastname': 'Lang',
#     'firstname': 'Jürg',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Jürg Lang',
#     'profession': [],
#     'places': ['Belgien', 'Zürich', 'Kopenhagen', 'Eth'],
#     'page': 'sbz-002_1965_083_3176.txt',
#     'year': '1965',
#     'coord': '841,1831,56,26'},
#    'label': '',
#    'mag-year': 'sbz-1965'},
#   {'ent': {'lastname': 'Lang',
#     'firstname': 'Jürg',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Jürg Lang',
#     'profession': [],
#     'places': ['Belgien', 'Zürich', 'Kopenhagen', 'Eth'],
#     'page': 'sbz-002_1965_083_3176.txt',
#     'year': '1965',
#     'coord': '903,1830,66,27'},
#    'label': '',
#    'mag-year': 'sbz-1965'},
#   {'ent': {'lastname': 'Lang',
#     'firstname': 'Jürg',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Jürg Lang',
#     'profession': [],
#     'places': ['Belgien', 'Zürich', 'Kopenhagen', 'Eth'],
#     'page': 'sbz-002_1965_083_3176.txt',
#     'year': '1965',
#     'coord': '788,2253,57,26'},
#    'label': '',
#    'mag-year': 'sbz-1965'},
#   {'ent': {'lastname': 'Lang',
#     'firstname': 'Jürg',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Jürg Lang',
#     'profession': [],
#     'places': ['Belgien', 'Zürich', 'Kopenhagen', 'Eth'],
#     'page': 'sbz-002_1965_083_3176.txt',
#     'year': '1965',
#     'coord': '855,2253,64,25'},
#    'label': '',
#    'mag-year': 'sbz-1965'}],
#  [{'ent': {'lastname': 'Maekawa',
#     'firstname': 'Kunio',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Kunio Maekawa',
#     'profession': [],
#     'places': ['Österreich',
#      'Irak',
#      'Japan',
#      'Finnland',
#      'Frankreich',
#      'Udssr',
#      'Usa'],
#     'page': 'sbz-002_1965_083_3176.txt',
#     'year': '1965',
#     'coord': '86,1242,79,23'},
#    'label': '119169754',
#    'mag-year': 'sbz-1965'},
#   {'ent': {'lastname': 'Maekawa',
#     'firstname': 'Kunio',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Kunio Maekawa',
#     'profession': [],
#     'places': ['Österreich',
#      'Irak',
#      'Japan',
#      'Finnland',
#      'Frankreich',
#      'Udssr',
#      'Usa'],
#     'page': 'sbz-002_1965_083_3176.txt',
#     'year': '1965',
#     'coord': '175,1242,128,26'},
#    'label': '119169754',
#    'mag-year': 'sbz-1965'}],
#  [{'ent': {'lastname': 'Makiya',
#     'firstname': 'Mohamed',
#     'abbr_firstname': ['S.'],
#     'other': [],
#     'name': 'Mohamed Makiya',
#     'profession': [],
#     'places': ['Österreich',
#      'Irak',
#      'Japan',
#      'Choindez',
#      'Udssr',
#      'Usa',
#      'Aarau',
#      'Finnland',
#      'Frankreich',
#      'Berlin'],
#     'page': 'sbz-002_1965_083_3176.txt',
#     'year': '1965',
#     'coord': '540,1241,23,21'},
#    'label': '119123207',
#    'mag-year': 'sbz-1965'},
#   {'ent': {'lastname': 'Makiya',
#     'firstname': 'Mohamed',
#     'abbr_firstname': ['S.'],
#     'other': [],
#     'name': 'Mohamed Makiya',
#     'profession': [],
#     'places': ['Österreich',
#      'Irak',
#      'Japan',
#      'Choindez',
#      'Udssr',
#      'Usa',
#      'Aarau',
#      'Finnland',
#      'Frankreich',
#      'Berlin'],
#     'page': 'sbz-002_1965_083_3176.txt',
#     'year': '1965',
#     'coord': '574,1240,102,27'},
#    'label': '119123207',
#    'mag-year': 'sbz-1965'},
#   {'ent': {'lastname': 'Makiya',
#     'firstname': 'Mohamed',
#     'abbr_firstname': ['S.'],
#     'other': [],
#     'name': 'Mohamed Makiya',
#     'profession': [],
#     'places': ['Österreich',
#      'Irak',
#      'Japan',
#      'Choindez',
#      'Udssr',
#      'Usa',
#      'Aarau',
#      'Finnland',
#      'Frankreich',
#      'Berlin'],
#     'page': 'sbz-002_1965_083_3176.txt',
#     'year': '1965',
#     'coord': '405,1240,127,23'},
#    'label': '119123207',
#    'mag-year': 'sbz-1965'}],
#  [{'ent': {'lastname': 'Nydegger',
#     'firstname': 'Andres',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Andres Nydegger',
#     'profession': [],
#     'places': ['Zürich'],
#     'page': 'sbz-002_1965_083_3176.txt',
#     'year': '1965',
#     'coord': '1682,2013,125,27'},
#    'label': '',
#    'mag-year': 'sbz-1965'},
#   {'ent': {'lastname': 'Nydegger',
#     'firstname': 'Andres',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Andres Nydegger',
#     'profession': [],
#     'places': ['Zürich'],
#     'page': 'sbz-002_1965_083_3176.txt',
#     'year': '1965',
#     'coord': '1587,2013,86,23'},
#    'label': '',
#    'mag-year': 'sbz-1965'}],
#  [{'ent': {'lastname': 'Rogii',
#     'firstname': 'Igor',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Igor Rogii',
#     'profession': [],
#     'places': ['Österreich',
#      'Irak',
#      'Japan',
#      'Finnland',
#      'Frankreich',
#      'Udssr',
#      'Usa'],
#     'page': 'sbz-002_1965_083_3176.txt',
#     'year': '1965',
#     'coord': '377,1201,100,38'},
#    'label': '',
#    'mag-year': 'sbz-1965'},
#   {'ent': {'lastname': 'Rogii',
#     'firstname': 'Igor',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Igor Rogii',
#     'profession': [],
#     'places': ['Österreich',
#      'Irak',
#      'Japan',
#      'Finnland',
#      'Frankreich',
#      'Udssr',
#      'Usa'],
#     'page': 'sbz-002_1965_083_3176.txt',
#     'year': '1965',
#     'coord': '313,1208,53,26'},
#    'label': '',
#    'mag-year': 'sbz-1965'}],
#  [{'ent': {'lastname': 'Schmidt',
#     'firstname': 'Gorm',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Gorm Schmidt',
#     'profession': [],
#     'places': ['Belgien', 'Zürich', 'Kopenhagen', 'Eth'],
#     'page': 'sbz-002_1965_083_3176.txt',
#     'year': '1965',
#     'coord': '522,1797,103,23'},
#    'label': '',
#    'mag-year': 'sbz-1965'},
#   {'ent': {'lastname': 'Schmidt',
#     'firstname': 'Gorm',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Gorm Schmidt',
#     'profession': [],
#     'places': ['Belgien', 'Zürich', 'Kopenhagen', 'Eth'],
#     'page': 'sbz-002_1965_083_3176.txt',
#     'year': '1965',
#     'coord': '439,1799,73,21'},
#    'label': '',
#    'mag-year': 'sbz-1965'},
#   {'ent': {'lastname': 'Schmidt',
#     'firstname': 'Gorm',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Gorm Schmidt',
#     'profession': [],
#     'places': ['Belgien', 'Zürich', 'Kopenhagen', 'Eth'],
#     'page': 'sbz-002_1965_083_3176.txt',
#     'year': '1965',
#     'coord': '489,1976,69,21'},
#    'label': '',
#    'mag-year': 'sbz-1965'},
#   {'ent': {'lastname': 'Schmidt',
#     'firstname': 'Gorm',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Gorm Schmidt',
#     'profession': [],
#     'places': ['Belgien', 'Zürich', 'Kopenhagen', 'Eth'],
#     'page': 'sbz-002_1965_083_3176.txt',
#     'year': '1965',
#     'coord': '569,1974,107,23'},
#    'label': '',
#    'mag-year': 'sbz-1965'}],
#  [{'ent': {'lastname': 'Schwanzer',
#     'firstname': 'Karl',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Karl Schwanzer',
#     'profession': [],
#     'places': ['Österreich',
#      'Irak',
#      'Japan',
#      'Finnland',
#      'Frankreich',
#      'Udssr',
#      'Usa'],
#     'page': 'sbz-002_1965_083_3176.txt',
#     'year': '1965',
#     'coord': '822,1238,141,26'},
#    'label': '118762885',
#    'mag-year': 'sbz-1965'},
#   {'ent': {'lastname': 'Schwanzer',
#     'firstname': 'Karl',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Karl Schwanzer',
#     'profession': [],
#     'places': ['Österreich',
#      'Irak',
#      'Japan',
#      'Finnland',
#      'Frankreich',
#      'Udssr',
#      'Usa'],
#     'page': 'sbz-002_1965_083_3176.txt',
#     'year': '1965',
#     'coord': '755,1239,57,22'},
#    'label': '118762885',
#    'mag-year': 'sbz-1965'}],
#  [{'ent': {'lastname': 'Sert',
#     'firstname': 'Jose Luis',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Jose Luis Sert',
#     'profession': [],
#     'places': ['Österreich',
#      'Irak',
#      'Japan',
#      'Finnland',
#      'Frankreich',
#      'Udssr',
#      'Usa'],
#     'page': 'sbz-002_1965_083_3176.txt',
#     'year': '1965',
#     'coord': '906,1169,57,26'},
#    'label': '118824856',
#    'mag-year': 'sbz-1965'},
#   {'ent': {'lastname': 'Sert',
#     'firstname': 'Jose Luis',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Jose Luis Sert',
#     'profession': [],
#     'places': ['Österreich',
#      'Irak',
#      'Japan',
#      'Finnland',
#      'Frankreich',
#      'Udssr',
#      'Usa'],
#     'page': 'sbz-002_1965_083_3176.txt',
#     'year': '1965',
#     'coord': '838,1170,55,22'},
#    'label': '118824856',
#    'mag-year': 'sbz-1965'},
#   {'ent': {'lastname': 'Sert',
#     'firstname': 'Jose Luis',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Jose Luis Sert',
#     'profession': [],
#     'places': ['Österreich',
#      'Irak',
#      'Japan',
#      'Finnland',
#      'Frankreich',
#      'Udssr',
#      'Usa'],
#     'page': 'sbz-002_1965_083_3176.txt',
#     'year': '1965',
#     'coord': '772,1170,54,23'},
#    'label': '118824856',
#    'mag-year': 'sbz-1965'}],
#  [{'ent': {'lastname': 'Siren',
#     'firstname': 'Heikki',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Heikki Siren',
#     'profession': [],
#     'places': ['Österreich',
#      'Irak',
#      'Japan',
#      'Finnland',
#      'Frankreich',
#      'Udssr',
#      'Usa'],
#     'page': 'sbz-002_1965_083_3176.txt',
#     'year': '1965',
#     'coord': '328,1274,71,27'},
#    'label': '119169746',
#    'mag-year': 'sbz-1965'},
#   {'ent': {'lastname': 'Siren',
#     'firstname': 'Heikki',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Heikki Siren',
#     'profession': [],
#     'places': ['Österreich',
#      'Irak',
#      'Japan',
#      'Finnland',
#      'Frankreich',
#      'Udssr',
#      'Usa'],
#     'page': 'sbz-002_1965_083_3176.txt',
#     'year': '1965',
#     'coord': '232,1275,86,23'},
#    'label': '119169746',
#    'mag-year': 'sbz-1965'}],
#  [{'ent': {'lastname': 'Dietsche',
#     'firstname': 'Daniela',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Daniela Dietsche',
#     'profession': [],
#     'places': ['Rhein'],
#     'page': 'sbz-004_2010_136_0891.txt',
#     'year': '2010',
#     'coord': '751,2649,89,32'},
#    'label': '1082006203',
#    'mag-year': 'sbz-2010'},
#   {'ent': {'lastname': 'Dietsche',
#     'firstname': 'Daniela',
#     'abbr_firstname': [],
#     'other': [],
#     'name': 'Daniela Dietsche',
#     'profession': [],
#     'places': ['Rhein'],
#     'page': 'sbz-004_2010_136_0891.txt',
#     'year': '2010',
#     'coord': '850,2649,110,32'},
#    'label': '1082006203',
#    'mag-year': 'sbz-2010'}]]

# %%
data_statistics_global_refs = dict()

for ent in data_statistics_global:
    for i in ent:
        if i["mag-year"] not in data_statistics_global_refs:
            data_statistics_global_refs.setdefault(i["mag-year"], {"linked_refs": 0, "total_refs": 0})
        
        data_statistics_global_refs[i["mag-year"]]["total_refs"] += 1
        if i["label"] != "":
            data_statistics_global_refs[i["mag-year"]]["linked_refs"] += 1

# %%
data_statistics_global_refs
# Out:
# {'dkm-1941': {'linked_refs': 27, 'total_refs': 83},
#  'dkm-2010': {'linked_refs': 569, 'total_refs': 613},
#  'sbz-1895': {'linked_refs': 82, 'total_refs': 122},
#  'sbz-1940': {'linked_refs': 137, 'total_refs': 258},
#  'sbz-1965': {'linked_refs': 276, 'total_refs': 565},
#  'sbz-2010': {'linked_refs': 169, 'total_refs': 351},
#  'dkm-1990': {'linked_refs': 617, 'total_refs': 728},
#  'sbz-1990': {'linked_refs': 87, 'total_refs': 195}}

# %%
"""
with open("data/processed.pkl", "wb") as f:
    pickle.dump(data, f)
"""

# %% [markdown]
# # Candidate Generation

# %%
import pickle
from tqdm.notebook import  tqdm
from candidate_generation import create_metagrid_candidates

# %%
def remove_obsolete_abbrevs(fnames, abbr_firstname, prep_for_query=True):
    """
    Remove abbreviated firstnames, that are already covered by full firstnames.
    e.g. fnames = ["R.", "Richard"] => fnames = ["Richard"]
    """
    cleaned_abbr_fnames = []
    for abbr_group in abbr_firstname:  # this is now a list
        cleaned_abbr_group = []
        for abbr in abbr_group:
            is_obsolete = False
            abbr = abbr.rstrip(".")
            for fname in fnames:
                if fname.startswith(abbr):
                    is_obsolete = True
            if not is_obsolete:
                if prep_for_query:
                    cleaned_abbr_group.append(abbr + "*")
                else:
                    cleaned_abbr_group.append(abbr + ".")
        cleaned_abbr_fnames.append(cleaned_abbr_group)
    
    return cleaned_abbr_fnames

# %%
import SPARQLWrapper
from SPARQLWrapper import JSON, SPARQLExceptions, SPARQLWrapper
import pprint as pp
def get_candidates_fuseki(person):
    """
    Call the RDF library to find candidates.
    Note to self: Consider limiting the query to top X answers if querying times are slow.
    """
    #unfortunately, checks like the one below doesn't find people like "Beethoven"
    if len(person["lastname"]) == 0 or (len([c for x in " ".join(person["lastname"]) for c in x]) < 2) or (not person["firstname"] and not person["abbr_firstname"]):
        return {}

    fnames = person["firstname"].split(" ")
    print(fnames)
    #fnames = list(set([x for y in fnames for x in y]))
    abbr_fnames = remove_obsolete_abbrevs(fnames, person["abbr_firstname"])
    abbr_fnames = list(set([x for y in abbr_fnames for x in y if x!="*"]))
    #abbr_fnames = " ".join(abbr_fnames)
    print(abbr_fnames)

    lastname = person["lastname"].split(" ")
    print(lastname)
    if fnames == [""]:
        names = " AND ".join(abbr_fnames + lastname)
    else:
        names = " AND ".join(fnames + abbr_fnames + lastname)
    print(names)
    if(len(lastname) > 1):
        lastname = " ".join(lastname)
    else:
        lastname = lastname[0]
    pref_names_format = lastname + ", " + " ".join(fnames) 
    query_string = """
        PREFIX gndo: <https://d-nb.info/standards/elementset/gnd#>
        PREFIX text: <http://jena.apache.org/text#>
        SELECT *
        WHERE {{
            {{?x text:query "{0}" . }}
            UNION
            {{?x text:query (gndo:variantNameForThePerson "{0}") . }}
            UNION
            {{?x gndo:preferredNameForThePerson ?s .
            FILTER (?s = "{1}") . }}
            # ?x a gndo:DifferentiatedPerson .
            # ?x gndo:gndIdentifier ?gid .
            # ?x gndo:preferredNameEntityForThePerson ?name .
            OPTIONAL {{ ?name gndo:prefferedNameForThePerson ?prefVarName . }}
            OPTIONAL {{ ?name gndo:forename ?prefForename . }}
            OPTIONAL {{ ?name gndo:prefix ?prefPrefix . }}
            OPTIONAL {{ ?name gndo:surname ?prefSurname . }}
            OPTIONAL {{ ?name gndo:personalName ?prefPersName . }}
            OPTIONAL {{ ?name gndo:nameAddition ?prefNameAddition . }}
            OPTIONAL {{ ?x gndo:variantNameEntityForThePerson ?y . 
                OPTIONAL {{ ?y gndo:variantNameForThePerson ?varName . }}
                OPTIONAL {{ ?y gndo:forename ?varForename . }}
                OPTIONAL {{ ?y gndo:prefix ?varPrefix . }}
                OPTIONAL {{ ?y gndo:surname ?varSurname . }}
                OPTIONAL {{ ?y gndo:personalName ?varPersName . }}
                OPTIONAL {{ ?y gndo:nameAddition ?varNameAddition . }}
            }}
            OPTIONAL {{ ?x gndo:professionOrOccupationAsLiteral ?jobliteral . }}
            OPTIONAL {{ ?x gndo:gndSubjectCategory ?category . }}
            OPTIONAL {{ ?x gndo:academicDegree ?academic . }}
            OPTIONAL {{ ?x gndo:professionOrOccupation ?job . }}
            OPTIONAL {{ ?x gndo:dateOfBirth ?birthdate . }}
            OPTIONAL {{ ?x gndo:dateOfDeath ?deathdate . }}
            OPTIONAL {{ ?x gndo:placeOfBirth ?birthplace . }}
            OPTIONAL {{ ?x gndo:placeOfDeath ?deathplace . }}
            OPTIONAL {{ ?x gndo:placeOfBirthAsLiteral ?birthplaceLiteral . }}
            OPTIONAL {{ ?x gndo:placeOfDeathAsLiteral ?deathplaceLiteral . }}
            OPTIONAL {{ ?x gndo:placeOfActivity ?activeplace . }}
            OPTIONAL {{ ?x gndo:periodOfActivity ?activeperiod . }}
            OPTIONAL {{ ?x gndo:biographicalOrHistoricalInformation ?desc . }}
            OPTIONAL {{ ?x gndo:geographicAreaCode ?generalArea . }}
            OPTIONAL {{ ?x gndo:affiliationAsLiteral ?affiliationLiteral . }}
        }}
        """.format(names, pref_names_format)
    endpoint = SPARQLWrapper("http://localhost:3030/persondata")
    endpoint.setQuery(query_string)
    endpoint.setReturnFormat(JSON)

    #print(query_string)
    try:
        results = endpoint.query().convert()
    except SPARQLExceptions.EndPointInternalError:
        pp.pprint("Invalid query")
        pp.pprint(query_string)
        #import sys;sys.exit()
        return {}
    except json.decoder.JSONDecodeError as e:
        pp.pprint(e)
        pp.pprint("Couldn't decode answer!")
        pp.pprint(query_string)
        return {}

    results = results["results"]["bindings"]
    if len(results) == 0:
        print("results is empty")
        print(names)
        #sys.exit()
        return {}
    else:
        print("sucessfully linked")
        #print(results)
   
    unique_candidate_dict = {}
    for result in results:
        uid = result["gid"]["value"]
        unique_candidate_dict.setdefault(uid, dict())
        for attname, attvalue in result.items():
            unique_candidate_dict[uid].setdefault(attname,set()).add(attvalue["value"])
    #now prepare the candidates the same way he did for metagrid:
    
    #print(unique_candidate_dict)
    return unique_candidate_dict

# %%
import requests, json
def extract_field_by_gnd(field, gnd_id, is_per = False):
    lobid_url = "http://lobid.org/gnd/"+gnd_id+".json"
    try:
        res = requests.get(lobid_url, timeout=5)
    except requests.ReadTimeout:
        return ""
    if (res.status_code != 200):
        return ""
    try:
        lobid_json = json.loads(res.text)
    except ValueError:
        print("this url: "+ lobid_url + " threw a json decode error")
        return ""
    if is_per:
        print(lobid_json.keys())
        field_list = []
        for i in lobid_json[field]:
            field_list.append(i["label"])
        return field_list
    else:
        #profession and place gnds
        return lobid_json["preferredName"]

# %%
import regex as re
from candidate_generation import get_coords_from_candidate
def process_fuseki_candidates(candidates):
    """
    fuseki candidates are given to us in the form:
    candidates created via fuseki is a dictionary with key gnd_id and the values are sets.
    example
    116272295
        "x" : {'https://d-nb.info/gn.../116272295'}
        "gid" : {'116272295'}
        "name" : {'b0'}
        "prefForename": {'Otto'}
        "prefSurname": {'Ahrens'}
        "y": {'b1'}
        "varForename": {'O.'}
        "varSurname": {'Ahrens'}
        "job": {'https://d-nb.info/gn.../4044300-0'}
        "activeplace":{'https://d-nb.info/gn.../4749047-0'}
        "activeperiod":{'1897'}
        "desc":{'Verf. von Mecklenburgica'}
        "generalArea":{'https://d-nb.info/st...code#XA-DE'}
    and depending on the info we have even more than this (birthdate, deathdate etc)
    """
    candidate_list = []

    for gnd_id in candidates:
        curr_cand = dict()
        curr_cand["Gnd"] = gnd_id

        curr_cand["PrefName"] = []
        curr_cand["FirstName"] = []
        curr_cand["LastName"] = []

        if "prefForename" in candidates[gnd_id]:
            firstnames_list = list(candidates[gnd_id]["prefForename"])
            curr_cand["FirstName"] += firstnames_list
        if "prefSurname" in candidates[gnd_id]:
            lastnames_list = list(candidates[gnd_id]["prefSurname"])
            curr_cand["LastName"] += lastnames_list
        
        if  "prefForename" in candidates[gnd_id] and "prefSurname" in candidates[gnd_id]:
            curr_cand["PrefName"] = [" ".join(curr_cand["LastName"]) + ", " + " ".join(curr_cand["FirstName"])]
        
        if curr_cand["FirstName"] == []:
            if "varForename" in candidates[gnd_id]:
                varfirstnames_list = list(candidates[gnd_id]["varForename"])
                curr_cand["FirstName"] += varfirstnames_list
        if curr_cand["LastName"] == []:
            if "varSurname" in candidates[gnd_id]:
                varlastnames_list = list(candidates[gnd_id]["varSurname"])
                curr_cand["LastName"] += varlastnames_list
        #we do not set prefName according to the varnames even if we have no prefnames.
        
        #take care of duplicates
        curr_cand["LastName"] = list(set(curr_cand["LastName"]))
        curr_cand["FirstName"] = list(set(curr_cand["FirstName"]))

        curr_cand["Biography"] = []
        if "desc" in candidates[gnd_id]:
            for i in candidates[gnd_id]["desc"]:
                curr_cand["Biography"].append(i)
        
        curr_cand["Places"] = []
        if "activeplace" in candidates[gnd_id]:
            for i in candidates[gnd_id]["activeplace"]:
                activeplace = extract_field_by_gnd("placeOfActivity", i.split("/")[-1], False)
                if activeplace != "":
                    curr_cand["Places"].append(activeplace)
        if "birthplace" in candidates[gnd_id]:
            for i in candidates[gnd_id]["birthplace"]:
                birthplace = extract_field_by_gnd("placeOfBirth", i.split("/")[-1], False)
                if birthplace != "":
                    curr_cand["Places"].append(birthplace)
        if "deathplace" in candidates[gnd_id]:
            for i in candidates[gnd_id]["deathplace"]:
                deathplace = extract_field_by_gnd("placeOfDeath", i.split("/")[-1], False)
                if deathplace != "":
                    curr_cand["Places"] .append(deathplace)
        if "generalArea" in candidates[gnd_id]:
            for i in candidates[gnd_id]["generalArea"]:
                general_area = extract_field_by_gnd("geographicAreaCode", i.split("/")[-1], False)
                if general_area != "":
                    curr_cand["Places"].append(general_area)
        
        curr_cand["Professions"] = []
        if "job" in candidates[gnd_id]:
            for i in candidates[gnd_id]["job"]:
                curr_job = extract_field_by_gnd("professionOrOccupation", i.split("/")[-1], False)
                curr_cand["Professions"].append(curr_job)
        
        curr_cand["Death Year"] = 0
        if "deathdate" in candidates[gnd_id]:
            dates = " ".join(candidates[gnd_id]["deathdate"])
            year_regex = re.findall(r'\d{4}', dates)
            year_regex.sort()
            if (len(year_regex) != 0):
                curr_cand["Death Year"] = int(year_regex[-1])
        curr_cand["Birth Year"] = 0
        if "birthdate" in candidates[gnd_id]:
            dates = " ".join(candidates[gnd_id]["birthdate"])
            year_regex = re.findall(r'\d{4}', dates)
            year_regex.sort()
            if (len(year_regex) != 0):
                curr_cand["Birth Year"] = int(year_regex[0])
                   
        curr_cand.update(get_coords_from_candidate(curr_cand))

        candidate_list.append(curr_cand)
    #and append the empty candidate
    empty_candidate = {'Gnd': '',
                        'PrefName': [],
                        'FirstName': [],
                        'LastName': [],
                        'Biography': [],
                        'Places': [],
                        'Professions': [],
                        'Death Year': 0,
                        'Birth Year': 0,
                        'coordinates': []}
    candidate_list.append(empty_candidate)
    return candidate_list

# %%
# load everytime you run this as we pop keys to keep data clean..
with open("data/processed.pkl", "rb") as f:
    data = pickle.load(f)

for split in ["train", "eval", "test"]:
    ent_cand_label = []
    i = 0
    for entity_list in tqdm(data[split], smoothing=0.01):
        i += 1
        # Create candidates only for the first entry in the list as all the entity information is always the same
        # The only thing that changes are pages and page_coordinates
        candidates = create_metagrid_candidates(ent=entity_list[0]["ent"])
        # Generate the list of page_coordinates and the corresponding labels!
        coord_list = []
        label_list = []
        for ent_dict in entity_list:
            ent = ent_dict["ent"]
            coord_list.append({
                "page": ent.pop("page", ""), 
                "coords": ent.pop("coord", "")
            })
            label_list.append(ent_dict["label"])
        ent_cand_label.append({"entity": ent, "candidates": candidates, "occurences": coord_list, "labels": label_list})
        if i % 100 == 0:
            with open(f"candidates-gnd-{split}.pkl", "wb") as f:
                pickle.dump(ent_cand_label, f)
                    
    with open(f"candidates-gnd-{split}.pkl", "wb") as f:
       pickle.dump(ent_cand_label, f)
# Out:
#   0%|          | 0/49 [00:00<?, ?it/s]
#   0%|          | 0/219 [00:00<?, ?it/s]

# %% [markdown]
# # Feature Generation

# %% [markdown]
# ### To get the relevant fastttext model uncomment and run the following cell

# %%
# from gensim.models.fasttext import FastText, load_facebook_vectors
# model = load_facebook_vectors("cc.de.300.bin/cc.de.300.bin")
# model.save("./fasttext")

# %%
import pickle
from tqdm.notebook import  tqdm
from feature_generation import candidates_to_features

# %%
#AF:
from tqdm import tqdm
# load everytime you run this as we pop keys to keep data clean..
with open("data/processed.pkl", "rb") as f:
    data = pickle.load(f)

problematic_entities = []
#for split in ["train", "eval", "test"]:
for split in ["train", "test"]:
#for split in ["eval"]:
    ent_cand_label = []
    i = 0
    for entity_list in tqdm(data[split], smoothing=0.01):
        i += 1
        # Create candidates only for the first entry in the list as all the entity information is always the same
        # The only thing that changes are pages and page_coordinates
        
        #fuseki:
        unique_candidate_dict = get_candidates_fuseki(entity_list[0]["ent"])
        candidates = process_fuseki_candidates(unique_candidate_dict)
        #print(process_fuseki_candidates(unique_candidate_dict))
        #list_of_tuples.append((ent, processed_fuseki_cands, ent_dict["label"]))
        
        #metagrid
        ## candidates = create_metagrid_candidates(ent=entity_list[0]["ent"])
        # Generate the list of page_coordinates and the corresponding labels!
        coord_list = []
        gt_label = []
        for ent_dict in entity_list:
            ent = ent_dict["ent"]
            coord_list.append({
                "page": ent.pop("page", ""), 
                "coords": ent.pop("coord", "")
            })
            gt_label.append(ent_dict["label"])

        #if len(gt_label)!=1:
        #    problematic_entities.append({"ent_list": entity_list, "gt_labels": gt_label, "mag": coord_list})
            

        #gt_label = gt_label.pop()
        
        ent_cand_label.append({"entity": ent, "candidates": candidates, "occurences": coord_list, "gt_label": gt_label})
        if i % 100 == 0:
            with open(f"data/candidates/candidates-gnd-{split}-{i}.pkl", "wb") as f:
                pickle.dump(ent_cand_label, f)
                    
    with open(f"data/candidates/candidates-gnd-{split}.pkl", "wb") as f:
       pickle.dump(ent_cand_label, f)
print(problematic_entities)
# Out:
#   0%|          | 0/574 [00:00<?, ?it/s]
#   0%|          | 0/49 [00:00<?, ?it/s]
#   0%|          | 0/219 [00:00<?, ?it/s]

# %% [markdown]
# # Feature Generation

# %%
from gensim.models.fasttext import FastText, load_facebook_vectors

# %%
#model = load_facebook_vectors("cc.de.300.bin/cc.de.300.bin")

# %%
#model.save("./fasttext")

# %%
import pickle
from tqdm import  tqdm
from feature_generation import create_features, get_gnd
# Out:
# C:\Users\genta\anaconda3\envs\cs4nlp\lib\site-packages\thefuzz\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
for split in ["train", "eval", "test"]:
#for split in ["eval"]:
    with open(f"data/candidates/candidates-gnd-{split}.pkl", "rb") as f:
        ent_cand_label = pickle.load(f)

    list_of_good_entities = []
    list_of_problematic_entities = []
    for ent_dict in tqdm(ent_cand_label):
        if len(set(ent_dict["labels"])) > 1:
            for label in set(ent_dict["labels"]):
                ent_dict["label"] = label
                features = candidates_to_features(ent=ent_dict["entity"], candidates=ent_dict["candidates"], gt_label=ent_dict["label"])
                ent_dict.update(features)
                list_of_problematic_entities.append(ent_dict.copy())
        else:
            ent_dict["label"] = set(ent_dict["labels"]).pop()
            features = candidates_to_features(ent=ent_dict["entity"], candidates=ent_dict["candidates"], gt_label=ent_dict["label"])
            ent_dict.update(features)
            list_of_good_entities.append(ent_dict)
            
    with open(f"data/features/{split}.pkl", "wb") as f:
        pickle.dump(list_of_good_entities, file=f)
    
    with open(f"data/features/{split}_problematic.pkl", "wb") as f:
        pickle.dump(list_of_problematic_entities, file=f)

# %% [markdown]
# # Ranking

# %% [markdown]
# ## Load Data

# %%
import pickle
from tqdm import tqdm
import numpy as np
from evaluation import perform_experiment, plot_metrics_over_threshold, crossvalidate_experiment

# %%
d = {"train": {}, "eval": {}}
for split in ["train", "eval"]:
    with open(f"data/features/fuseki/{split}.pkl", "rb") as f:
        d[split] = pickle.load(file=f)

d_problem = {"train": {}, "eval": {}}
for split in ["train", "eval"]:
    with open(f"data/features/fuseki/{split}_problematic.pkl", "rb") as f:
        d_problem[split] = pickle.load(file=f)

d_combined = {"train": d["train"] + d_problem["train"], "eval": d["eval"] + d_problem["eval"]}

# %%
d = {"train": {}, "test": {}}
for split in ["train", "test"]:
    with open(f"data/features/fuseki/{split}.pkl", "rb") as f:
        d[split] = pickle.load(file=f)

d_problem = {"train": {}, "test": {}}
for split in ["train", "test"]:
    with open(f"data/features/fuseki/{split}_problematic.pkl", "rb") as f:
        d_problem[split] = pickle.load(file=f)

d_combined = {"train": d["train"] + d_problem["train"], "test": d["test"] + d_problem["test"]}

# %%
from sklearn.ensemble import ExtraTreesRegressor

# %% [markdown]
# **Best scores I could get so far, Fuseki candidates**

# %%
ent_scores, ment_scores = perform_experiment(
    keep_empty=False,
    do_sample=True,
    oversampling=3, # Multiple of how often we oversample y = 1
    balance=2, # multiple of y = 0 samples vs y = 1 samples
    train=d_combined["train"],
    eval=d_combined["test"],
    model=ExtraTreesRegressor(n_estimators=100, random_state=0, criterion="squared_error", bootstrap=True),
    n_s=[1,10], # How many candidates do we keep
    thresholds=[0.2], # Where do we cut off
    verbose=False # Print stuff
)

# %%
ent_scores, ment_scores = crossvalidate_experiment(
    d = d,
    n_fold = 5,
    keep_empty=True,
    do_sample=True,
    oversampling=2, # Multiple of how often we oversample y = 1
    balance=3, # multiple of y = 0 samples vs y = 1 samples
    model=ExtraTreesRegressor(n_estimators=100, random_state=0, criterion="squared_error", bootstrap=True),
    n_s=[1,10], # How many candidates do we keep
    thresholds=[0.01, 0.1, 0.2, 0.3, 0.5], # Where do we cut off
    verbose=False # Print stuff
)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [94], in <cell line: 1>()
# ----> 1 ent_scores, ment_scores = crossvalidate_experiment(
#       2     d = d,
#       3     n_fold = 5,
#       4     keep_empty=True,
#       5     do_sample=True,
#       6     oversampling=2, # Multiple of how often we oversample y = 1
#       7     balance=3, # multiple of y = 0 samples vs y = 1 samples
#       8     model=ExtraTreesRegressor(n_estimators=100, random_state=0, criterion="squared_error", bootstrap=True),
#       9     n_s=[1,10], # How many candidates do we keep
#      10     thresholds=[0.01, 0.1, 0.2, 0.3,0.5], # Where do we cut off
#      11     verbose=False # Print stuff
#      12 )
#
# File ~\git\ETH-CS4NLP-22-Project-Linking-GND\evaluation.py:201, in crossvalidate_experiment(d, n_fold, keep_empty, do_sample, oversampling, balance, model, n_s, thresholds, verbose)
#     199 train = data[:lb]+ data[ub:]
#     200 eval = data[lb:ub]
# --> 201 ent_scores, ment_scores = perform_experiment(
#     202     keep_empty=keep_empty,
#     203     do_sample=do_sample,
#     204     oversampling=oversampling,
#     205     balance=balance,
#     206     model=model,
#     207     n_s=n_s,
#     208     thresholds=thresholds,
#     209     train=train,
#     210     eval=eval,
#     211     verbose=verbose)
#     212 ent_scores_crossval.append(ent_scores)
#     213 ment_scores_crossval.append(ment_scores)
#
# File ~\git\ETH-CS4NLP-22-Project-Linking-GND\evaluation.py:171, in perform_experiment(keep_empty, do_sample, oversampling, balance, model, n_s, thresholds, train, eval, verbose)
#     168 model.fit(X_sample, y_sample)
#     170 for entity in eval:
# --> 171     ranking = rank_candidates(candidates=entity["candidates"], features=entity["features"], model=model)
#     172     entity.update(ranking)
#     174 ent_scores = []
#
# File ~\git\ETH-CS4NLP-22-Project-Linking-GND\evaluation.py:57, in rank_candidates(candidates, features, model)
#      55 candidate_ids = []
#      56 for candidate, feature in zip(candidates, features):
# ---> 57     score = model.predict(np.array(feature).reshape(1,-1))[0]
#      58     candidate_scores.append(score)
#      59     candidate_ids.append(get_gnd(candidate))
#
# File ~\anaconda3\envs\cs4nlp\lib\site-packages\sklearn\ensemble\_forest.py:1004, in ForestRegressor.predict(self, X)
#    1002 # Parallel loop
#    1003 lock = threading.Lock()
# -> 1004 Parallel(n_jobs=n_jobs, verbose=self.verbose, require="sharedmem")(
#    1005     delayed(_accumulate_prediction)(e.predict, X, [y_hat], lock)
#    1006     for e in self.estimators_
#    1007 )
#    1009 y_hat /= len(self.estimators_)
#    1011 return y_hat
#
# File ~\anaconda3\envs\cs4nlp\lib\site-packages\joblib\parallel.py:1046, in Parallel.__call__(self, iterable)
#    1043 if self.dispatch_one_batch(iterator):
#    1044     self._iterating = self._original_iterator is not None
# -> 1046 while self.dispatch_one_batch(iterator):
#    1047     pass
#    1049 if pre_dispatch == "all" or n_jobs == 1:
#    1050     # The iterable was consumed all at once by the above for loop.
#    1051     # No need to wait for async callbacks to trigger to
#    1052     # consumption.
#
# File ~\anaconda3\envs\cs4nlp\lib\site-packages\joblib\parallel.py:861, in Parallel.dispatch_one_batch(self, iterator)
#     859     return False
#     860 else:
# --> 861     self._dispatch(tasks)
#     862     return True
#
# File ~\anaconda3\envs\cs4nlp\lib\site-packages\joblib\parallel.py:779, in Parallel._dispatch(self, batch)
#     777 with self._lock:
#     778     job_idx = len(self._jobs)
# --> 779     job = self._backend.apply_async(batch, callback=cb)
#     780     # A job can complete so quickly than its callback is
#     781     # called before we get here, causing self._jobs to
#     782     # grow. To ensure correct results ordering, .insert is
#     783     # used (rather than .append) in the following line
#     784     self._jobs.insert(job_idx, job)
#
# File ~\anaconda3\envs\cs4nlp\lib\site-packages\joblib\_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File ~\anaconda3\envs\cs4nlp\lib\site-packages\joblib\_parallel_backends.py:572, in ImmediateResult.__init__(self, batch)
#     569 def __init__(self, batch):
#     570     # Don't delay the application, to avoid keeping the input
#     571     # arguments in memory
# --> 572     self.results = batch()
#
# File ~\anaconda3\envs\cs4nlp\lib\site-packages\joblib\parallel.py:262, in BatchedCalls.__call__(self)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# File ~\anaconda3\envs\cs4nlp\lib\site-packages\joblib\parallel.py:262, in <listcomp>(.0)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# File ~\anaconda3\envs\cs4nlp\lib\site-packages\sklearn\utils\fixes.py:117, in _FuncWrapper.__call__(self, *args, **kwargs)
#     115 def __call__(self, *args, **kwargs):
#     116     with config_context(**self.config):
# --> 117         return self.function(*args, **kwargs)
#
# File ~\anaconda3\envs\cs4nlp\lib\site-packages\sklearn\ensemble\_forest.py:664, in _accumulate_prediction(predict, X, out, lock)
#     657 def _accumulate_prediction(predict, X, out, lock):
#     658     """
#     659     This is a utility function for joblib's Parallel.
#     660
#     661     It can't go locally in ForestClassifier or ForestRegressor, because joblib
#     662     complains that it cannot pickle it when placed there.
#     663     """
# --> 664     prediction = predict(X, check_input=False)
#     665     with lock:
#     666         if len(out) == 1:
#
# File ~\anaconda3\envs\cs4nlp\lib\site-packages\sklearn\tree\_classes.py:506, in BaseDecisionTree.predict(self, X, check_input)
#     504 check_is_fitted(self)
#     505 X = self._validate_X_predict(X, check_input)
# --> 506 proba = self.tree_.predict(X)
#     507 n_samples = X.shape[0]
#     509 # Classification
#
# KeyboardInterrupt:

# %%
print("\nEntity Level")
for score in ent_scores:
    print("N:", score["top_n"], "Threshold:", score["threshold"])
    score["score"].print_scores()

print("Mention Level")
for score in ment_scores:
    print("N:", score["top_n"], "Threshold:", score["threshold"])
    score["score"].print_scores()
# Out:
# Entity Level
# N: 1 Threshold: 0.2
# F1: 0.407 RE:  0.269 PR: 0.839 AC: 0.419
# TP: 47 FN: 128 FP 9 TN 52
#
#
# N: 10 Threshold: 0.2
# F1: 0.421 RE:  0.28 PR: 0.845 AC: 0.428
# TP: 49 FN: 126 FP 9 TN 52
#
#
# Mention Level
# N: 1 Threshold: 0.2
# F1: 0.69 RE:  0.552 PR: 0.921 AC: 0.602
# TP: 526 FN: 427 FP 45 TN 187
#
#
# N: 10 Threshold: 0.2
# F1: 0.695 RE:  0.558 PR: 0.922 AC: 0.607
# TP: 532 FN: 421 FP 45 TN 187

# %%
print("\nEntity Level")
for score in ent_scores:
    print("N:", score["top_n"], "Threshold:", score["threshold"])
    score["score"].print_scores()

print("Mention Level")
for score in ment_scores:
    print("N:", score["top_n"], "Threshold:", score["threshold"])
    score["score"].print_scores()
# Out:
# Entity Level
# N: 1 Treshold: 0.01
# F1: 0.484 RE:  0.319 PR: 1.0 AC: 0.611
# TP: 23 FN: 49 FP 0 TN 54
#
#
# N: 1 Treshold: 0.1
# F1: 0.473 RE:  0.31 PR: 1.0 AC: 0.608
# TP: 22 FN: 49 FP 0 TN 54
#
#
# N: 1 Treshold: 0.3
# F1: 0.468 RE:  0.306 PR: 1.0 AC: 0.603
# TP: 22 FN: 50 FP 0 TN 54
#
#
# N: 1 Treshold: 0.5
# F1: 0.452 RE:  0.292 PR: 1.0 AC: 0.595
# TP: 21 FN: 51 FP 0 TN 54
#
#
# N: 10 Treshold: 0.01
# F1: 0.536 RE:  0.366 PR: 1.0 AC: 0.64
# TP: 26 FN: 45 FP 0 TN 54
#
#
# N: 10 Treshold: 0.1
# F1: 0.515 RE:  0.347 PR: 1.0 AC: 0.627
# TP: 25 FN: 47 FP 0 TN 54
#
#
# N: 10 Treshold: 0.3
# F1: 0.5 RE:  0.333 PR: 1.0 AC: 0.619
# TP: 24 FN: 48 FP 0 TN 54
#
#
# N: 10 Treshold: 0.5
# F1: 0.468 RE:  0.306 PR: 1.0 AC: 0.603
# TP: 22 FN: 50 FP 0 TN 54
#
#
# Mention Level
# N: 1 Treshold: 0.01
# F1: 0.632 RE:  0.463 PR: 0.992 AC: 0.654
# TP: 120 FN: 139 FP 1 TN 145
#
#
# N: 1 Treshold: 0.1
# F1: 0.628 RE:  0.459 PR: 0.992 AC: 0.652
# TP: 119 FN: 140 FP 1 TN 145
#
#
# N: 1 Treshold: 0.3
# F1: 0.621 RE:  0.452 PR: 0.992 AC: 0.647
# TP: 117 FN: 142 FP 1 TN 145
#
#
# N: 1 Treshold: 0.5
# F1: 0.613 RE:  0.444 PR: 0.991 AC: 0.642
# TP: 115 FN: 144 FP 1 TN 145
#
#
# N: 10 Treshold: 0.01
# F1: 0.668 RE:  0.502 PR: 1.0 AC: 0.682
# TP: 130 FN: 129 FP 0 TN 147
#
#
# N: 10 Treshold: 0.1
# F1: 0.658 RE:  0.49 PR: 1.0 AC: 0.675
# TP: 127 FN: 132 FP 0 TN 147
#
#
# N: 10 Treshold: 0.3
# F1: 0.644 RE:  0.475 PR: 1.0 AC: 0.665
# TP: 123 FN: 136 FP 0 TN 147
#
#
# N: 10 Treshold: 0.5
# F1: 0.626 RE:  0.456 PR: 1.0 AC: 0.653
# TP: 118 FN: 141 FP 0 TN 147

# %%
from sklearn.ensemble import ExtraTreesClassifier, ExtraTreesRegressor
from sklearn.linear_model import ElasticNet
from sklearn.ensemble import GradientBoostingRegressor

models = [
    GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, max_depth=1, random_state=0, loss='squared_error'),
    #ExtraTreesRegressor(n_estimators=100, random_state=0, criterion="squared_error", bootstrap=True),
    ExtraTreesRegressor(n_estimators=100, random_state=0, criterion="absolute_error", bootstrap=True),
    ExtraTreesClassifier(n_estimators=100, random_state=0, bootstrap=True),
    ElasticNet(random_state=0)
    ## NN ??
]

model_names = ["GBR", 
               #"Tree Reg Squared", 
               "Tree Reg Abs", "Tree Class", "Elastic"]

# %%
models = [ExtraTreesRegressor(n_estimators=100, random_state=0, criterion="squared_error", bootstrap=True)]
model_names = ["Tree Reg Squared"]

# %%
balance_list = [2, 3]
oversampling_list = [2, 3]
n_s = [1,10]
thresholds = [0.01, 0.1, 0.2]

# %%
model_results = []

for model, model_name in zip(models, model_names):
    print(model_name)
    results = []
    for data, data_name in zip([d, d_combined], ["cleaned", "combined"]):
        print("Data:", data_name)
        for keep_empty in [True, False]:
            print("keep_empty:", keep_empty)
            for do_sample in [True, False]:
                print("do_sample:", do_sample)
                if do_sample:
                    for balance in balance_list:
                        print("Balance:", balance)
                        for oversampling in oversampling_list:
                            print("Oversampling:", oversampling)
                            ent_scores, ment_scores = crossvalidate_experiment(
                                    d = data,
                                    n_fold = 5,
                                    keep_empty=keep_empty,
                                    do_sample=do_sample, 
                                    oversampling=oversampling, 
                                    balance=balance,
                                    model=model,
                                    n_s=n_s,
                                    thresholds=thresholds,
                                    verbose=False 
                                )
                            results.append({
                                "keep_empty": keep_empty,
                                "do_sample": do_sample,
                                "balance": balance,
                                "oversampling": oversampling,
                                "ent_scores": ent_scores,
                                "ment_scores": ment_scores,
                                "model": model_name,
                                "data": data_name
                            })
                else:
                    balance = 1
                    oversampling = 1 
                    ent_scores, ment_scores = crossvalidate_experiment(
                            d = data,
                            n_fold = 5,
                            keep_empty=keep_empty,
                            do_sample=do_sample, 
                            oversampling=oversampling, 
                            balance=balance,
                            model=model,
                            n_s=n_s,
                            thresholds=thresholds,
                            verbose=False 
                        )
                    results.append({
                        "keep_empty": keep_empty,
                        "do_sample": do_sample,
                        "balance": balance,
                        "oversampling": oversampling,
                        "ent_scores": ent_scores,
                        "ment_scores": ment_scores,
                        "model": model_name,
                        "data": data_name
                    })
    model_results.append(results)
# Out:
# Tree Reg Squared
# Data: cleaned
# keep_empty: True
# do_sample: True
# Balance: 2
# Oversampling: 2
# Oversampling: 3
# Balance: 3
# Oversampling: 2
# Oversampling: 3
# do_sample: False
# keep_empty: False
# do_sample: True
# Balance: 2
# Oversampling: 2
# Oversampling: 3
# Balance: 3
# Oversampling: 2
# Oversampling: 3
# do_sample: False
# Data: combined
# keep_empty: True
# do_sample: True
# Balance: 2
# Oversampling: 2
# Oversampling: 3
# Balance: 3
# Oversampling: 2
# Oversampling: 3
# do_sample: False
# keep_empty: False
# do_sample: True
# Balance: 2
# Oversampling: 2
# Oversampling: 3
# Balance: 3
# Oversampling: 2
# Oversampling: 3
# do_sample: False

# %%
#check out the model results model_results
#with open('model_results.pkl', 'wb') as out:
#     pickle.dump(model_results, out)

# %%
#my_results = pickle.load(open('model_results.pkl', 'rb'))
#(my_results)
# Out:
# [[{'keep_empty': True,
#    'do_sample': True,
#    'balance': 2,
#    'oversampling': 2,
#    'ent_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x2662382ad70>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x266214f9c90>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x266214fac50>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x266214f9000>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x266214fa710>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x266214fbac0>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x266214f8100>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x266214fa8c0>}],
#    'ment_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x266214f97b0>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x266214f8250>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x266214f85e0>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x266214fbeb0>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x266214f9240>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x266214f96f0>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x266214fb7f0>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x266214f9a80>}],
#    'model': 'GBR',
#    'data': 'cleaned'},
#   {'keep_empty': True,
#    'do_sample': True,
#    'balance': 2,
#    'oversampling': 3,
#    'ent_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x266214fb370>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x266214fb670>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x266214f9510>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x266214fa920>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x266214f80a0>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x266214fa950>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x266214f8dc0>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x266214f8af0>}],
#    'ment_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x266214f8490>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x266214fa9e0>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x266214f92d0>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x266214fbf70>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x266214f9300>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x266214fa170>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x266214faef0>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x266214f9600>}],
#    'model': 'GBR',
#    'data': 'cleaned'},
#   {'keep_empty': True,
#    'do_sample': True,
#    'balance': 3,
#    'oversampling': 2,
#    'ent_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x266214fa410>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x266214f8610>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26622831b70>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26622833910>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26622831420>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26622831150>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x266228304c0>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26622830970>}],
#    'ment_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26622832b60>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26622831960>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x266228306d0>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26622832d70>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26622830fd0>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26622831f90>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26622831e10>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26622833c70>}],
#    'model': 'GBR',
#    'data': 'cleaned'},
#   {'keep_empty': True,
#    'do_sample': True,
#    'balance': 3,
#    'oversampling': 3,
#    'ent_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26622830520>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26622832200>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26622833700>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x266228322f0>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26622832080>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x266217188e0>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626a982b0>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626a995a0>}],
#    'ment_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626a98820>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626a981f0>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626a98640>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626a991b0>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626a983a0>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626a99600>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626a99120>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626a98f40>}],
#    'model': 'GBR',
#    'data': 'cleaned'},
#   {'keep_empty': True,
#    'do_sample': False,
#    'balance': 1,
#    'oversampling': 1,
#    'ent_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626a985b0>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626a98880>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626a99240>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626a99210>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626a99540>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626a99000>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626a989a0>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626a984f0>}],
#    'ment_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626a99750>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626a98250>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626a98fd0>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626a98430>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626a99360>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626a98a90>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626a98850>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626a98910>}],
#    'model': 'GBR',
#    'data': 'cleaned'},
#   {'keep_empty': False,
#    'do_sample': True,
#    'balance': 2,
#    'oversampling': 2,
#    'ent_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626a99150>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626a98fa0>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626a993f0>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626a99060>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626a98610>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626a99510>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626b14160>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626b14430>}],
#    'ment_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626b165f0>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626b14280>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626b14790>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626b16a70>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626b144f0>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626b16620>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626b148e0>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626b14dc0>}],
#    'model': 'GBR',
#    'data': 'cleaned'},
#   {'keep_empty': False,
#    'do_sample': True,
#    'balance': 2,
#    'oversampling': 3,
#    'ent_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626b14610>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626b14910>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626b14b50>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626b16b90>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626b14d90>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626b16bc0>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626b14550>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626b16b60>}],
#    'ment_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626b165c0>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626b168c0>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626b142b0>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626b14640>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626b14730>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626b16770>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626b16c80>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626b16cb0>}],
#    'model': 'GBR',
#    'data': 'cleaned'},
#   {'keep_empty': False,
#    'do_sample': True,
#    'balance': 3,
#    'oversampling': 2,
#    'ent_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626b167d0>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626b14460>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626b14bb0>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626b147c0>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626b16aa0>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626b16980>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626b16b00>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626b14400>}],
#    'ment_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626b146a0>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626b14c70>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626b16a10>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626b14d30>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626b14040>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626b167a0>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626b14a60>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626b16800>}],
#    'model': 'GBR',
#    'data': 'cleaned'},
#   {'keep_empty': False,
#    'do_sample': True,
#    'balance': 3,
#    'oversampling': 3,
#    'ent_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626b14340>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626b14100>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626b14310>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626b14700>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626b16650>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626b14850>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626b14be0>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626b14880>}],
#    'ment_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626b143d0>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x2662376d300>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26623735120>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26623734bb0>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26623735630>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x266237349d0>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26623734790>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26623737400>}],
#    'model': 'GBR',
#    'data': 'cleaned'},
#   {'keep_empty': False,
#    'do_sample': False,
#    'balance': 1,
#    'oversampling': 1,
#    'ent_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26623736620>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26623736440>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26623736320>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26623736590>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26623734c10>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26623734f40>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26623734310>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26623735e70>}],
#    'ment_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x266237366e0>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26623736200>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x266237355a0>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26623734130>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26623736da0>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26623736770>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26623737c70>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x266237370d0>}],
#    'model': 'GBR',
#    'data': 'cleaned'},
#   {'keep_empty': True,
#    'do_sample': True,
#    'balance': 2,
#    'oversampling': 2,
#    'ent_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26623734f10>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26623735d20>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26623736530>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26623737fd0>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26623737040>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26623735000>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x266237367a0>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26623734490>}],
#    'ment_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26623737070>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26623737490>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x266237350f0>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26623736b90>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26623736ef0>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x266237365c0>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26623737e20>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26623735f30>}],
#    'model': 'GBR',
#    'data': 'combined'},
#   {'keep_empty': True,
#    'do_sample': True,
#    'balance': 2,
#    'oversampling': 3,
#    'ent_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26623737250>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26623737d00>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x266237377f0>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x266237350c0>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26623737be0>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26623736890>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x266237361d0>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26623737760>}],
#    'ment_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26623734220>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x266237369b0>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x266237341c0>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26623737d60>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26623735480>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26623735720>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26623734100>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26623737670>}],
#    'model': 'GBR',
#    'data': 'combined'},
#   {'keep_empty': True,
#    'do_sample': True,
#    'balance': 3,
#    'oversampling': 2,
#    'ent_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26623736050>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x266237370a0>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26623737c10>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26623734400>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26623736350>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26623734eb0>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26623737a60>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26623737eb0>}],
#    'ment_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26623735990>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26623734850>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x266237344f0>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26623735090>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26623735930>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x266237369e0>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26623734a30>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26623736980>}],
#    'model': 'GBR',
#    'data': 'combined'},
#   {'keep_empty': True,
#    'do_sample': True,
#    'balance': 3,
#    'oversampling': 3,
#    'ent_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26623736a40>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x266237348e0>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x266237360b0>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26623735ff0>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x266236f05e0>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x266236f1030>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x266236f0dc0>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x266217bf3a0>}],
#    'ment_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626b705b0>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626b70b50>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626b70850>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626b714b0>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626b707f0>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626b70af0>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626b709d0>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626b71ab0>}],
#    'model': 'GBR',
#    'data': 'combined'},
#   {'keep_empty': True,
#    'do_sample': False,
#    'balance': 1,
#    'oversampling': 1,
#    'ent_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626b71ba0>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626b702b0>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626b70b20>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626b70160>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626b706a0>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626b707c0>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626b701c0>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626b708e0>}],
#    'ment_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626b719f0>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626b71a50>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626b70640>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626b70790>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626b70700>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626b700a0>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626b71b40>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626b70d60>}],
#    'model': 'GBR',
#    'data': 'combined'},
#   {'keep_empty': False,
#    'do_sample': True,
#    'balance': 2,
#    'oversampling': 2,
#    'ent_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626b71ae0>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626b70be0>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626b70c10>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626b71a80>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626b703a0>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626b708b0>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626b70760>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626b715a0>}],
#    'ment_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626b70bb0>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626b71750>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626b70ca0>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626b70730>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626b70370>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626b70100>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626b709a0>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626b70610>}],
#    'model': 'GBR',
#    'data': 'combined'},
#   {'keep_empty': False,
#    'do_sample': True,
#    'balance': 2,
#    'oversampling': 3,
#    'ent_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626b71600>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626b71b10>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626b704f0>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626b705e0>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626b70cd0>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x266217a5690>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x266217a7e20>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x266217a4190>}],
#    'ment_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x266217a6050>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x266217a7a00>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x266217a62f0>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x266217a65f0>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x266217a4820>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x266217a6380>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626bdc070>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626bdc0d0>}],
#    'model': 'GBR',
#    'data': 'combined'},
#   {'keep_empty': False,
#    'do_sample': True,
#    'balance': 3,
#    'oversampling': 2,
#    'ent_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626bdc130>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626bdc190>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626bdc1f0>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626bdc250>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626bdc2b0>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626bdc310>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626bdc370>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626bdc3d0>}],
#    'ment_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626bdc430>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626bdc490>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626bdc4f0>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626bdc550>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626bdc5b0>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626bdc610>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626bdc670>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626bdc6d0>}],
#    'model': 'GBR',
#    'data': 'combined'},
#   {'keep_empty': False,
#    'do_sample': True,
#    'balance': 3,
#    'oversampling': 3,
#    'ent_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626bdc730>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626bdc790>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626bdc7f0>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626bdc850>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626bdc8b0>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626bdc910>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626bdc970>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626bdc9d0>}],
#    'ment_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626bdca30>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626bdca90>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626bdcaf0>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626bdcb50>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626bdcbb0>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626bdcc10>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626bdcc70>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626bdccd0>}],
#    'model': 'GBR',
#    'data': 'combined'},
#   {'keep_empty': False,
#    'do_sample': False,
#    'balance': 1,
#    'oversampling': 1,
#    'ent_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626bdcd30>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626bdcd90>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626bdcdf0>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626bdce50>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626bdceb0>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626bdcf10>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626bdcf70>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626bdcfd0>}],
#    'ment_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626bdd030>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626bdd090>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626bdd0f0>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626bdd150>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626bdd1b0>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626bdd210>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626bdd270>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626bdd2d0>}],
#    'model': 'GBR',
#    'data': 'combined'}],
#  [{'keep_empty': True,
#    'do_sample': True,
#    'balance': 2,
#    'oversampling': 2,
#    'ent_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626bdd330>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626bdd390>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626bdd3f0>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626bdd450>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626bdd4b0>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626bdd510>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626bdd570>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626bdd5d0>}],
#    'ment_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626bdd630>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626bdd690>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626bdd6f0>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626bdd750>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626bdd7b0>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626bdd810>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626bdd870>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626bdd8d0>}],
#    'model': 'Tree Reg Abs',
#    'data': 'cleaned'},
#   {'keep_empty': True,
#    'do_sample': True,
#    'balance': 2,
#    'oversampling': 3,
#    'ent_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626bdd930>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626bdd990>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626bdd9f0>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626bdda50>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626bddab0>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626bddb10>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626bddb70>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626bddbd0>}],
#    'ment_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626bddc30>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626bddc90>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626bddcf0>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626bddd50>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626bdddb0>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626bdde10>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626bdde70>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626bdded0>}],
#    'model': 'Tree Reg Abs',
#    'data': 'cleaned'},
#   {'keep_empty': True,
#    'do_sample': True,
#    'balance': 3,
#    'oversampling': 2,
#    'ent_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626bddf30>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626bddf90>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626bddff0>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626bde050>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626bde0b0>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626bde110>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626bde170>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626bde1d0>}],
#    'ment_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626bde230>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626bde290>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626bde2f0>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626bde350>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626bde3b0>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626bde410>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626bde470>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626bde4d0>}],
#    'model': 'Tree Reg Abs',
#    'data': 'cleaned'},
#   {'keep_empty': True,
#    'do_sample': True,
#    'balance': 3,
#    'oversampling': 3,
#    'ent_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626bde530>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626bde590>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626bde5f0>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626bde650>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626bde6b0>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626bde710>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626bde770>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626bde7d0>}],
#    'ment_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626bde830>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626bde890>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626bde8f0>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626bde950>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626bde9b0>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626bdea10>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626bdea70>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626bdead0>}],
#    'model': 'Tree Reg Abs',
#    'data': 'cleaned'},
#   {'keep_empty': True,
#    'do_sample': False,
#    'balance': 1,
#    'oversampling': 1,
#    'ent_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626bdeb30>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626bdeb90>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626bdebf0>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626bdec50>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626bdecb0>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626bded10>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626bded70>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626bdedd0>}],
#    'ment_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626bdee30>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626bdee90>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626bdeef0>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626bdef50>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626bdefb0>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626bdf010>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626bdf070>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626bdf0d0>}],
#    'model': 'Tree Reg Abs',
#    'data': 'cleaned'},
#   {'keep_empty': False,
#    'do_sample': True,
#    'balance': 2,
#    'oversampling': 2,
#    'ent_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626bdf130>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626bdf190>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626bdf1f0>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626bdf250>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626bdf2b0>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626bdf310>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626bdf370>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626bdf3d0>}],
#    'ment_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626bdf430>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626bdf490>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626bdf4f0>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626bdf550>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626bdf5b0>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626bdf610>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626bdf670>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626bdf6d0>}],
#    'model': 'Tree Reg Abs',
#    'data': 'cleaned'},
#   {'keep_empty': False,
#    'do_sample': True,
#    'balance': 2,
#    'oversampling': 3,
#    'ent_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626bdf730>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626bdf790>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626bdf7f0>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626bdf850>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626bdf8b0>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626bdf910>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626bdf970>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626bdf9d0>}],
#    'ment_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626bdfa30>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626bdfa90>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626bdfaf0>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626bdfb50>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626bdfbb0>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626bdfc10>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626bdfc70>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626bdfcd0>}],
#    'model': 'Tree Reg Abs',
#    'data': 'cleaned'},
#   {'keep_empty': False,
#    'do_sample': True,
#    'balance': 3,
#    'oversampling': 2,
#    'ent_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626bdfd30>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626bdfd90>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626bdfdf0>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626bdfe50>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626bdfeb0>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626bdff10>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626bdff70>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626bdffd0>}],
#    'ment_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626bd8070>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626bd80d0>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626bd8130>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626bd8190>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626bd81f0>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626bd8250>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626bd82b0>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626bd8310>}],
#    'model': 'Tree Reg Abs',
#    'data': 'cleaned'},
#   {'keep_empty': False,
#    'do_sample': True,
#    'balance': 3,
#    'oversampling': 3,
#    'ent_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626bd8370>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626bd83d0>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626bd8430>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626bd8490>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626bd84f0>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626bd8550>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626bd85b0>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626bd8610>}],
#    'ment_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626bd8670>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626bd86d0>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626bd8730>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626bd8790>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626bd87f0>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626bd8850>},
#     {'top_n': 10,
#      'threshold': 0.2,
# ...
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626c682b0>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626c68310>}],
#    'ment_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626c68370>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626c683d0>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626c68430>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626c68490>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626c684f0>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626c68550>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626c685b0>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626c68610>}],
#    'model': 'Elastic',
#    'data': 'combined'},
#   {'keep_empty': True,
#    'do_sample': True,
#    'balance': 2,
#    'oversampling': 3,
#    'ent_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626c68670>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626c686d0>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626c68730>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626c68790>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626c687f0>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626c68850>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626c688b0>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626c68910>}],
#    'ment_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626c68970>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626c689d0>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626c68a30>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626c68a90>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626c68af0>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626c68b50>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626c68bb0>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626c68c10>}],
#    'model': 'Elastic',
#    'data': 'combined'},
#   {'keep_empty': True,
#    'do_sample': True,
#    'balance': 3,
#    'oversampling': 2,
#    'ent_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626c68c70>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626c68cd0>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626c68d30>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626c68d90>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626c68df0>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626c68e50>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626c68eb0>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626c68f10>}],
#    'ment_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626c68f70>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626c68fd0>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626c69030>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626c69090>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626c690f0>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626c69150>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626c691b0>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626c69210>}],
#    'model': 'Elastic',
#    'data': 'combined'},
#   {'keep_empty': True,
#    'do_sample': True,
#    'balance': 3,
#    'oversampling': 3,
#    'ent_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626c69270>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626c692d0>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626c69330>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626c69390>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626c693f0>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626c69450>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626c694b0>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626c69510>}],
#    'ment_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626c69570>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626c695d0>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626c69630>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626c69690>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626c696f0>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626c69750>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626c697b0>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626c69810>}],
#    'model': 'Elastic',
#    'data': 'combined'},
#   {'keep_empty': True,
#    'do_sample': False,
#    'balance': 1,
#    'oversampling': 1,
#    'ent_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626c69870>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626c698d0>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626c69930>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626c69990>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626c699f0>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626c69a50>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626c69ab0>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626c69b10>}],
#    'ment_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626c69b70>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626c69bd0>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626c69c30>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626c69c90>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626c69cf0>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626c69d50>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626c69db0>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626c69e10>}],
#    'model': 'Elastic',
#    'data': 'combined'},
#   {'keep_empty': False,
#    'do_sample': True,
#    'balance': 2,
#    'oversampling': 2,
#    'ent_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626c69e70>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626c69ed0>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626c69f60>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626c69ff0>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626c6a080>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626c6a110>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626c6a1a0>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626c6a230>}],
#    'ment_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626c6a2c0>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626c6a350>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626c6a3e0>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626c6a470>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626c6a500>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626c6a590>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626c6a620>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626c6a6b0>}],
#    'model': 'Elastic',
#    'data': 'combined'},
#   {'keep_empty': False,
#    'do_sample': True,
#    'balance': 2,
#    'oversampling': 3,
#    'ent_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626c6a740>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626c6a7d0>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626c6a860>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626c6a8f0>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626c6a980>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626c6aa10>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626c6aaa0>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626c6ab30>}],
#    'ment_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626c6abc0>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626c6ac50>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626c6ace0>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626c6ad70>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626c6ae00>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626c6ae90>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626c6af20>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626c6afb0>}],
#    'model': 'Elastic',
#    'data': 'combined'},
#   {'keep_empty': False,
#    'do_sample': True,
#    'balance': 3,
#    'oversampling': 2,
#    'ent_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626c6b040>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626c6b0d0>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626c6b160>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626c6b1f0>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626c6b280>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626c6b310>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626c6b3a0>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626c6b430>}],
#    'ment_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626c6b4c0>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626c6b550>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626c6b5e0>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626c6b670>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626c6b700>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626c6b790>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626c6b820>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626c6b8b0>}],
#    'model': 'Elastic',
#    'data': 'combined'},
#   {'keep_empty': False,
#    'do_sample': True,
#    'balance': 3,
#    'oversampling': 3,
#    'ent_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626c6b940>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626c6b9d0>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626c6ba60>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626c6baf0>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626c6bb80>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626c6bc10>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626c6bca0>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626c6bd30>}],
#    'ment_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626c6bdc0>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626c6be50>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626c6bee0>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626c6bf70>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626c90040>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626c900d0>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626c90160>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626c901f0>}],
#    'model': 'Elastic',
#    'data': 'combined'},
#   {'keep_empty': False,
#    'do_sample': False,
#    'balance': 1,
#    'oversampling': 1,
#    'ent_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626c90280>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626c90310>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626c903a0>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626c90430>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626c904c0>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626c90550>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626c905e0>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626c90670>}],
#    'ment_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626c90700>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626c90790>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626c90820>},
#     {'top_n': 1,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626c908b0>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626c90940>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626c909d0>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626c90a60>},
#     {'top_n': 10,
#      'threshold': 0.5,
#      'score': <evaluation.Scores at 0x26626c90af0>}],
#    'model': 'Elastic',
#    'data': 'combined'}]]

# %%
my_results = model_results.copy()
my_results
# Out:
# [[{'keep_empty': True,
#    'do_sample': True,
#    'balance': 2,
#    'oversampling': 2,
#    'ent_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26629469b10>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x266236ed780>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x266236ef2e0>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x266236efd60>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x266236eea70>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x266236effa0>}],
#    'ment_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626a98df0>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x266236eec50>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x266236ed000>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x266236ecaf0>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x266236ec340>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x266236ec190>}],
#    'model': 'Tree Reg Squared',
#    'data': 'cleaned'},
#   {'keep_empty': True,
#    'do_sample': True,
#    'balance': 2,
#    'oversampling': 3,
#    'ent_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x266232c1cc0>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x266269f93c0>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x2662373a890>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x266236a8ca0>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x266236a8bb0>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x266236aafb0>}],
#    'ment_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26629e541c0>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x266237399c0>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26629469810>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x266236ab160>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x266236aa380>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x266236abfa0>}],
#    'model': 'Tree Reg Squared',
#    'data': 'cleaned'},
#   {'keep_empty': True,
#    'do_sample': True,
#    'balance': 3,
#    'oversampling': 2,
#    'ent_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626c6ada0>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x2662abc6320>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x2662700de10>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x266237b8460>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x266237b87c0>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x266237b8a00>}],
#    'ment_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x266272b0130>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x266217bfa30>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x266236ee0e0>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x266237ba440>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x266237bb1f0>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x266237bad10>}],
#    'model': 'Tree Reg Squared',
#    'data': 'cleaned'},
#   {'keep_empty': True,
#    'do_sample': True,
#    'balance': 3,
#    'oversampling': 3,
#    'ent_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x266236e3b80>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x266285ddc00>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x266237181c0>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26623734250>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626ff2320>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626ff3d30>}],
#    'ment_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x266232c1900>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x2662371bc70>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26623719c30>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x266237352d0>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626ff1750>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626ff3640>}],
#    'model': 'Tree Reg Squared',
#    'data': 'cleaned'},
#   {'keep_empty': True,
#    'do_sample': False,
#    'balance': 1,
#    'oversampling': 1,
#    'ent_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26629e27d90>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26623286aa0>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26623286650>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26623286590>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x266236f3b20>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x266236f0d90>}],
#    'ment_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x266272b0160>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26623286890>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x266232866b0>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x2662179c430>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x266236f1f60>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x266236f0370>}],
#    'model': 'Tree Reg Squared',
#    'data': 'cleaned'},
#   {'keep_empty': False,
#    'do_sample': True,
#    'balance': 2,
#    'oversampling': 2,
#    'ent_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x266237393c0>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x266228329e0>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26622833c10>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26622830c10>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26627048a00>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26612411030>}],
#    'ment_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x266269c6110>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x266228336d0>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26622832aa0>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26622833370>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26612410c10>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26612410b20>}],
#    'model': 'Tree Reg Squared',
#    'data': 'cleaned'},
#   {'keep_empty': False,
#    'do_sample': True,
#    'balance': 2,
#    'oversampling': 3,
#    'ent_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x266285ecca0>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x2662382af20>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x266238292a0>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x266238285e0>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26623828a30>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26623828f40>}],
#    'ment_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x2662374e8f0>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x266238283d0>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26623828700>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x266238286a0>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x2662382b520>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x266238284f0>}],
#    'model': 'Tree Reg Squared',
#    'data': 'cleaned'},
#   {'keep_empty': False,
#    'do_sample': True,
#    'balance': 3,
#    'oversampling': 2,
#    'ent_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x2662179d4b0>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626ff3310>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626ff3d00>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626ff14e0>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626ff3670>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x266237bba60>}],
#    'ment_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x2662325c070>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626ff2e30>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626ff06d0>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626ff2d40>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626ff2f80>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x266236f37f0>}],
#    'model': 'Tree Reg Squared',
#    'data': 'cleaned'},
#   {'keep_empty': False,
#    'do_sample': True,
#    'balance': 3,
#    'oversampling': 3,
#    'ent_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x266236ece50>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26623811240>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x266236aa6b0>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x266236a97e0>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x266236a9000>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x266236ab0d0>}],
#    'ment_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x266236ed2a0>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x266236aaec0>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x266236a89d0>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x266236a9600>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x266236aa6e0>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x266236a8e20>}],
#    'model': 'Tree Reg Squared',
#    'data': 'cleaned'},
#   {'keep_empty': False,
#    'do_sample': False,
#    'balance': 1,
#    'oversampling': 1,
#    'ent_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626b71780>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x266237caf50>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x2662700edd0>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x2662700dcc0>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x2662700d420>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x2662700e4a0>}],
#    'ment_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626ff12a0>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x2662700ef50>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x2662700fd60>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x2662700f730>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x2662700da50>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x2662700d540>}],
#    'model': 'Tree Reg Squared',
#    'data': 'cleaned'},
#   {'keep_empty': True,
#    'do_sample': True,
#    'balance': 2,
#    'oversampling': 2,
#    'ent_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x266285de230>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26627071300>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26627072710>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26627072230>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x266270707c0>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26627073ca0>}],
#    'ment_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x266285de2f0>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26627071540>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26627071270>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26627073d00>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x266270727d0>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x266270729e0>}],
#    'model': 'Tree Reg Squared',
#    'data': 'combined'},
#   {'keep_empty': True,
#    'do_sample': True,
#    'balance': 2,
#    'oversampling': 3,
#    'ent_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26629e545e0>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x2662371ba60>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26623812ce0>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26623810cd0>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26623812b60>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626c6b850>}],
#    'ment_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x2662371aaa0>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x2662371b040>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26623810670>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x266238116c0>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626c6bfa0>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626c6af50>}],
#    'model': 'Tree Reg Squared',
#    'data': 'combined'},
#   {'keep_empty': True,
#    'do_sample': True,
#    'balance': 3,
#    'oversampling': 2,
#    'ent_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x266285ecc10>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26623718430>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26623719c60>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x2662371a1a0>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26623718160>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x266237199f0>}],
#    'ment_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x266228332b0>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x2662371acb0>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26623718910>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x2662371b7f0>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26623718fd0>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x2662371ae00>}],
#    'model': 'Tree Reg Squared',
#    'data': 'combined'},
#   {'keep_empty': True,
#    'do_sample': True,
#    'balance': 3,
#    'oversampling': 3,
#    'ent_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26623286800>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x266217a4ee0>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x266236a9510>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x2662700fe50>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26623828670>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26623828400>}],
#    'ment_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x266217257b0>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x266236aa0b0>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x2662700f370>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26623828490>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x2662382a200>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x266269c65f0>}],
#    'model': 'Tree Reg Squared',
#    'data': 'combined'},
#   {'keep_empty': True,
#    'do_sample': False,
#    'balance': 1,
#    'oversampling': 1,
#    'ent_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26623813c40>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626ff20b0>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626ff1510>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626ff3400>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626ff30a0>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626fa6a10>}],
#    'ment_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x266269c7490>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626ff0df0>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626ff1090>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626ff1450>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626ff3e20>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626f98ac0>}],
#    'model': 'Tree Reg Squared',
#    'data': 'combined'},
#   {'keep_empty': False,
#    'do_sample': True,
#    'balance': 2,
#    'oversampling': 2,
#    'ent_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x266237b8eb0>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x266237bb550>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x266237b95d0>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x266237bb1c0>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x266237bb010>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x266237b90f0>}],
#    'ment_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x266237bb8e0>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x266237b9480>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x266237ba5c0>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x266237b86d0>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x266237b8f70>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x266237b84f0>}],
#    'model': 'Tree Reg Squared',
#    'data': 'combined'},
#   {'keep_empty': False,
#    'do_sample': True,
#    'balance': 2,
#    'oversampling': 3,
#    'ent_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26623078700>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626fc09d0>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626fc1db0>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626fc1150>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626fc3970>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626fc0ac0>}],
#    'ment_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26623077910>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626fc3c40>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626fc24d0>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626fc18d0>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626fc1120>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626fc11b0>}],
#    'model': 'Tree Reg Squared',
#    'data': 'combined'},
#   {'keep_empty': False,
#    'do_sample': True,
#    'balance': 3,
#    'oversampling': 2,
#    'ent_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x266227dc9a0>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626fc39d0>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626fc30a0>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626fc1c30>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626fc1c60>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626fc24a0>}],
#    'ment_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26622830b20>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626fc3a60>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626fc2590>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626fc1570>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x26626fc2bc0>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26626fc2bf0>}],
#    'model': 'Tree Reg Squared',
#    'data': 'combined'},
#   {'keep_empty': False,
#    'do_sample': True,
#    'balance': 3,
#    'oversampling': 3,
#    'ent_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26626c6b2b0>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x266236ee5c0>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x266236edd80>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x266236ef490>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x266236ed210>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x266236ecd90>}],
#    'ment_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26623737190>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x266236ed840>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x266236ec250>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x266236ef730>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x266236ef8e0>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x266236edba0>}],
#    'model': 'Tree Reg Squared',
#    'data': 'combined'},
#   {'keep_empty': False,
#    'do_sample': False,
#    'balance': 1,
#    'oversampling': 1,
#    'ent_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x266272b01f0>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x266269c5750>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x266236aa980>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x266236a8c10>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x266236a9180>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x2662371a950>}],
#    'ment_scores': [{'top_n': 1,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x26623735330>},
#     {'top_n': 1,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x266236ab520>},
#     {'top_n': 1,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x266236aa770>},
#     {'top_n': 10,
#      'threshold': 0.01,
#      'score': <evaluation.Scores at 0x266236ab340>},
#     {'top_n': 10,
#      'threshold': 0.1,
#      'score': <evaluation.Scores at 0x2662371b0d0>},
#     {'top_n': 10,
#      'threshold': 0.2,
#      'score': <evaluation.Scores at 0x26623718640>}],
#    'model': 'Tree Reg Squared',
#    'data': 'combined'}]]

# %%
do_sample = True
keep_empty = True
model = "Tree Reg Squared"
data = "combined"

for balance in balance_list:
    for oversampling in oversampling_list:
        plot_metrics_over_treshold(
            tresholds=tresholds, 
            n_s=n_s, 
            oversampling=oversampling, 
            balance=balance, 
            do_sample=True, 
            keep_empty=True, 
            model=model,
            data=data,
            results=results)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [49], in <cell line: 6>()
#       6 for balance in balance_list:
#       7     for oversampling in oversampling_list:
# ----> 8         plot_metrics_over_treshold(
#       9             tresholds=tresholds,
#      10             n_s=n_s,
#      11             oversampling=oversampling,
#      12             balance=balance,
#      13             do_sample=True,
#      14             keep_empty=True,
#      15             model=model,
#      16             data=data,
#      17             results=results)
#
# NameError: name 'plot_metrics_over_treshold' is not defined

# %%
# top_10 scores are necessarily better than top_1 scores, here we can decide which one we choose to get metrics about
top_n = 10

# %%
def extract(scores, score_name, dict, current_setup, top_n):
    for score in scores:
        score_dict = score["score"].get_score()
        if score["top_n"] == top_n:
            curr_setup["top_n"] = score["top_n"]
            curr_setup["threshold"] = score["threshold"]
            if score_dict[score_name] > dict[f"top_{score_name}"]:
                dict[f"top_{score_name}"] = score_dict[score_name]
                dict[f"top_{score_name}_setup"] = [current_setup]
            elif score_dict[score_name] == dict[f"top_{score_name}"]:
                dict[f"top_{score_name}_setup"].append(current_setup)
        #print(dict)
    return dict

model_results = []
for model_name in model_names:
    dictionary={
        "ent": {
            "top_F1": 0,
            "top_Recall": 0,
            "top_Precision": 0,
            "top_F1_setup": [],
            "top_Recall_setup": [],
            "top_Precision_setup": []
        },
        "ment": {
            "top_F1": 0,
            "top_Recall": 0,
            "top_Precision": 0,
            "top_F1_setup": [],
            "top_Recall_setup": [],
            "top_Precision_setup": []
        }
    }
    for di in my_results:
        for entry in di:
            if entry["model"] == model_name:
                for scoring_level in ["ent", "ment"]:
                    scores = entry[f"{scoring_level}_scores"]
                    curr_setup = {
                        "data": entry["data"],
                        "do_sample": entry["do_sample"],
                        "balance": entry["balance"],
                        "oversampling": entry["oversampling"],
                        "keep_empty": entry["keep_empty"]
                    }
                    for score_name in ["F1", "Recall", "Precision"]:
                        dictionary[scoring_level] = extract(scores, score_name, dictionary[scoring_level], curr_setup, top_n=top_n )
    model_results.append(dictionary)

# %%
score = "F1"

# %%
model_results
# Out:
# [{'ent': {'top_F1': 0,
#    'top_Recall': 0,
#    'top_Precision': 0,
#    'top_F1_setup': [],
#    'top_Recall_setup': [],
#    'top_Precision_setup': []},
#   'ment': {'top_F1': 0,
#    'top_Recall': 0,
#    'top_Precision': 0,
#    'top_F1_setup': [],
#    'top_Recall_setup': [],
#    'top_Precision_setup': []}}]

# %%
for scores, model_name in zip(model_results, model_names):
    balance = []
    combined = []
    oversampling = []
    keep_empty = []
    do_sample = []
    top_n = []
    tresholds = []
    print(model_name)
    for scoring_level in ["ent", "ment"]:
        print(f"{scoring_level}\t", f"{score}:\t", scores[scoring_level][f"top_{score}"])
        print(f"{scoring_level}\t", f"{score} Setup:")
        for setup in scores[scoring_level][f"top_{score}_setup"]:
            if setup["data"] == "cleaned":
                combined.append(0)
            else:
                combined.append(1)
            balance.append(setup["balance"])
            oversampling.append(setup["oversampling"])
            top_n.append(setup["top_n"])
            tresholds.append(setup["threshold"])
            if setup["do_sample"]:
                do_sample.append(1)
            else:
                do_sample.append(0)
            if setup["keep_empty"]:
                keep_empty.append(1)
            else:
                keep_empty.append(0)
    
        print(f"Number of setups: {len(do_sample)}")

        print("Mean")
        print("sample", np.mean(do_sample))
        print("empty ", np.mean(keep_empty))
        print("combin", np.mean(combined))
        print("tresh ", np.mean(tresholds))
        print("top_n ", np.mean(top_n))
        print("overs ", np.mean(oversampling))
        print("balanc", np.mean(balance))

        print("Median")
        print("sample", np.median(do_sample))
        print("empty ", np.median(keep_empty))
        print("combin", np.median(combined))
        print("tresh ", np.median(tresholds))
        print("top_n ", np.median(top_n))
        print("overs ", np.median(oversampling))
        print("balanc", np.median(balance))
        print("\n\n")
# Out:
# Tree Reg Squared
# ent	 F1:	 0.724
# ent	 F1 Setup:
# Number of setups: 3
# Mean
# sample 1.0
# empty  1.0
# combin 0.0
# tresh  0.20000000000000004
# top_n  10.0
# overs  2.6666666666666665
# balanc 2.3333333333333335
# Median
# sample 1.0
# empty  1.0
# combin 0.0
# tresh  0.2
# top_n  10.0
# overs  3.0
# balanc 2.0
#
#
#
# ment	 F1:	 0.848
# ment	 F1 Setup:
# Number of setups: 6
# Mean
# sample 1.0
# empty  1.0
# combin 0.0
# tresh  0.19999999999999998
# top_n  10.0
# overs  2.6666666666666665
# balanc 2.3333333333333335
# Median
# sample 1.0
# empty  1.0
# combin 0.0
# tresh  0.2
# top_n  10.0
# overs  3.0
# balanc 2.0

# %% [markdown]
# After some tests we find:
# - ExtraTreesRegressor works best
# - with:
#     - Balance = 1
#     - Oversampling = 1
#     - do_sample = True
#     - keep_empty = True
#     - treshold = 0.1 or smaller is more stable in advers conditions for balance 1 and oversampling 1 it does not matter -> this makes the regression more stable
#     - => n -> does not matter so much can amolst go to 1 !!!!
#
# - problematic entities seem to help
